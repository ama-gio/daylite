# %% [markdown]
# # LIBRARIES

# %%
#run only once, 
# !pip install ghhops-server flask-ngrok
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ghhops-server
#   Downloading ghhops_server-1.5.3-py2.py3-none-any.whl (11 kB)
# Collecting flask-ngrok
#   Downloading flask_ngrok-0.0.25-py3-none-any.whl (3.1 kB)
# Collecting rhino3dm
#   Downloading rhino3dm-7.14.2.tar.gz (5.7 MB)
#      |████████████████████████████████| 5.7 MB 8.2 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from flask-ngrok) (2.23.0)
# Requirement already satisfied: Flask>=0.8 in /usr/local/lib/python3.7/dist-packages (from flask-ngrok) (1.1.4)
# Requirement already satisfied: click<8.0,>=5.1 in /usr/local/lib/python3.7/dist-packages (from Flask>=0.8->flask-ngrok) (7.1.2)
# Requirement already satisfied: Werkzeug<2.0,>=0.15 in /usr/local/lib/python3.7/dist-packages (from Flask>=0.8->flask-ngrok) (1.0.1)
# Requirement already satisfied: itsdangerous<2.0,>=0.24 in /usr/local/lib/python3.7/dist-packages (from Flask>=0.8->flask-ngrok) (1.1.0)
# Requirement already satisfied: Jinja2<3.0,>=2.10.1 in /usr/local/lib/python3.7/dist-packages (from Flask>=0.8->flask-ngrok) (2.11.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2<3.0,>=2.10.1->Flask>=0.8->flask-ngrok) (2.0.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->flask-ngrok) (2022.6.15)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->flask-ngrok) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->flask-ngrok) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->flask-ngrok) (1.24.3)
# Building wheels for collected packages: rhino3dm
#   Building wheel for rhino3dm (setup.py) ... done
#   Created wheel for rhino3dm: filename=rhino3dm-7.14.2-cp37-cp37m-linux_x86_64.whl size=4995202 sha256=b30d036ef6add990204d8076cec9ddbad23091c12e44effa0551b4d48c411e36
#   Stored in directory: /root/.cache/pip/wheels/54/fd/27/c1c91b5631a9dcb2291a8541117b0040fe461756f9c77430fc
# Successfully built rhino3dm
# Installing collected packages: rhino3dm, ghhops-server, flask-ngrok
# Successfully installed flask-ngrok-0.0.25 ghhops-server-1.5.3 rhino3dm-7.14.2

# %%
# Import standard Libraries
import pandas as pd
import seaborn as sns
import altair as alt
import tensorflow as tf
import matplotlib.pyplot as plt
import joblib
from flask import Flask
from flask_ngrok import run_with_ngrok
import ghhops_server as hs
import numpy
import rhino3dm


sns.set(rc={'figure.figsize':(10,10)})
print("imports ok")
# Out:
# imports ok

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # LOAD/SCALING

# %%
# Load data file
data = pd.read_csv('/content/gdrive/MyDrive/0.Thesis/binnedData_Combined.csv')
pd.options.display.max_columns = None

data.head()
# Out:
#    myIndex  roomNumber  FloorHeight      Width  Length  Rotation  \
# 0        0           0          8.0  31.666667    14.0     -22.0
# 1        1           0          8.0  31.666667    14.0     -22.0
# 2        2           0          8.0  31.666667    14.0     -22.0
# 3        3           0          8.0  31.666667    14.0     -22.0
# 4        5           0          8.0  31.666667    14.0     -22.0
#
#    SouthContextOffset  EastContextOffset  NorthContextOffset  \
# 0                  69                 12                  11
# 1                  69                 12                  11
# 2                  69                 12                  11
# 3                  69                 12                  11
# 4                  69                 12                  11
#
#    WestContextOffset  SouthContextHeight  EastContextHeight  \
# 0                 71                 161                125
# 1                 71                 161                125
# 2                 71                 161                125
# 3                 71                 161                125
# 4                 71                 161                125
#
#    NorthContextHeight  WestContextHeight  SouthShadingDepth  EastShadingDepth  \
# 0                 472                142               1.96               1.4
# 1                 472                142               1.96               1.4
# 2                 472                142               1.96               1.4
# 3                 472                142               1.96               1.4
# 4                 472                142               1.96               1.4
#
#    NorthShadingDepth  WestShadingDepth  NorthGlazingRatio  WestGlazingRatio  \
# 0               1.93              2.11                0.2               0.3
# 1               1.93              2.11                0.0               0.3
# 2               1.93              2.11                0.0               0.3
# 3               1.93              2.11                0.2               0.0
# 4               1.93              2.11                0.0               0.0
#
#    SouthGlazingRatio  EastGlazingRatio  NorthWindowHeight  WestWindowHeight  \
# 0                0.0               0.0                  0                 4
# 1                0.0               0.0                  0                 4
# 2                0.7               0.0                  0                 4
# 3                0.0               0.0                  0                 4
# 4                0.7               0.0                  0                 4
#
#    SouthWindowHeight  EastWindowHeight  NorthWindowSill  WestWindowSill  \
# 0                  6                 8                5               1
# 1                  6                 8                5               1
# 2                  6                 8                5               1
# 3                  6                 8                5               1
# 4                  6                 8                5               1
#
#    SouthWindowSill  EastWindowSill  Location     sDA        UDI    ASE  \
# 0                0               2         1   40.80  79.145797   5.82
# 1                0               2         1   22.73  39.574263   4.76
# 2                0               2         1  100.00  47.284580  57.77
# 3                0               2         1    0.00  47.657260   0.00
# 4                0               2         1  100.00  63.463152  42.63
#
#              sDABin            UDIBin           ASEBin  sDA_Category  \
# 0   (13.762, 45.29]  (76.594, 86.843]   (2.194, 14.51]             2
# 1   (13.762, 45.29]  (34.682, 60.449]   (2.194, 14.51]             2
# 2     (87.5, 100.0]  (34.682, 60.449]   (40.55, 100.0]             4
# 3  (-0.001, 13.762]  (34.682, 60.449]  (-0.001, 2.194]             1
# 4     (87.5, 100.0]  (60.449, 76.594]   (40.55, 100.0]             4
#
#    UDI_Category  ASE_Category
# 0             4             2
# 1             2             2
# 2             2             4
# 3             2             1
# 4             3             4

# %%
#declare features (ROBOTIC PARAMETERS)
x = data.iloc[:,2:-9]

# Load and instantiate a StandardScalar 
from sklearn.preprocessing import StandardScaler
scalerX = StandardScaler()

# Apply the scaler to the inputs
X_scaled = scalerX.fit_transform(x)

print(X_scaled.shape)

x.head()
# Out:
# (27432, 29)
#    FloorHeight      Width  Length  Rotation  SouthContextOffset  \
# 0          8.0  31.666667    14.0     -22.0                  69
# 1          8.0  31.666667    14.0     -22.0                  69
# 2          8.0  31.666667    14.0     -22.0                  69
# 3          8.0  31.666667    14.0     -22.0                  69
# 4          8.0  31.666667    14.0     -22.0                  69
#
#    EastContextOffset  NorthContextOffset  WestContextOffset  \
# 0                 12                  11                 71
# 1                 12                  11                 71
# 2                 12                  11                 71
# 3                 12                  11                 71
# 4                 12                  11                 71
#
#    SouthContextHeight  EastContextHeight  NorthContextHeight  \
# 0                 161                125                 472
# 1                 161                125                 472
# 2                 161                125                 472
# 3                 161                125                 472
# 4                 161                125                 472
#
#    WestContextHeight  SouthShadingDepth  EastShadingDepth  NorthShadingDepth  \
# 0                142               1.96               1.4               1.93
# 1                142               1.96               1.4               1.93
# 2                142               1.96               1.4               1.93
# 3                142               1.96               1.4               1.93
# 4                142               1.96               1.4               1.93
#
#    WestShadingDepth  NorthGlazingRatio  WestGlazingRatio  SouthGlazingRatio  \
# 0              2.11                0.2               0.3                0.0
# 1              2.11                0.0               0.3                0.0
# 2              2.11                0.0               0.3                0.7
# 3              2.11                0.2               0.0                0.0
# 4              2.11                0.0               0.0                0.7
#
#    EastGlazingRatio  NorthWindowHeight  WestWindowHeight  SouthWindowHeight  \
# 0               0.0                  0                 4                  6
# 1               0.0                  0                 4                  6
# 2               0.0                  0                 4                  6
# 3               0.0                  0                 4                  6
# 4               0.0                  0                 4                  6
#
#    EastWindowHeight  NorthWindowSill  WestWindowSill  SouthWindowSill  \
# 0                 8                5               1                0
# 1                 8                5               1                0
# 2                 8                5               1                0
# 3                 8                5               1                0
# 4                 8                5               1                0
#
#    EastWindowSill  Location
# 0               2         1
# 1               2         1
# 2               2         1
# 3               2         1
# 4               2         1

# %%
#declare regression target - (VESSEL POINTS)

y = data.iloc[:,-9:-6]

# Load and instantiate a StandardScalar 
from sklearn.preprocessing import MinMaxScaler
scalerY = MinMaxScaler()

# Apply the scaler to the outputs
y_scaled = scalerY.fit_transform(y)

print(y_scaled.shape)

y.head()
# Out:
# (27432, 3)
#       sDA        UDI    ASE
# 0   40.80  79.145797   5.82
# 1   22.73  39.574263   4.76
# 2  100.00  47.284580  57.77
# 3    0.00  47.657260   0.00
# 4  100.00  63.463152  42.63

# %% [markdown]
# # TRAINING

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size = 0.2, random_state = 20)

# %%
# Instantiate a sequential model
tf.random.set_seed(5)
modelANN = tf.keras.Model()
modelANN = tf.keras.models.Sequential()
n_cols = X_scaled.shape[1]  

# Add 3 dense layers of 64 and 32, 16 neurons each
modelANN.add(tf.keras.layers.Dense(64, input_shape=(n_cols,), activation='relu'))
modelANN.add(tf.keras.layers.Dense(32, input_shape=(n_cols,), activation='relu'))
modelANN.add(tf.keras.layers.Dense(16, activation='relu'))
  
# Add a dense layer with 3 value output
modelANN.add(tf.keras.layers.Dense(3, activation= "sigmoid"))
  
# Compile your model 
modelANN.compile(optimizer = "adam", loss = "mean_squared_error", metrics = ["accuracy"])

# %%
modelANN.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                1920
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 16)                528
#
#  dense_3 (Dense)             (None, 3)                 51
#
# =================================================================
# Total params: 4,579
# Trainable params: 4,579
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = modelANN.fit(X_train,y_train, epochs=200, validation_split=0.2)
# Out:
# Epoch 1/200
# 549/549 [==============================] - 2s 3ms/step - loss: 0.0393 - accuracy: 0.8521 - val_loss: 0.0175 - val_accuracy: 0.9116
# Epoch 2/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0139 - accuracy: 0.9195 - val_loss: 0.0115 - val_accuracy: 0.9237
# Epoch 3/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0101 - accuracy: 0.9260 - val_loss: 0.0088 - val_accuracy: 0.9264
# Epoch 4/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0081 - accuracy: 0.9299 - val_loss: 0.0075 - val_accuracy: 0.9335
# Epoch 5/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0069 - accuracy: 0.9327 - val_loss: 0.0067 - val_accuracy: 0.9326
# Epoch 6/200
# 549/549 [==============================] - 2s 3ms/step - loss: 0.0062 - accuracy: 0.9350 - val_loss: 0.0062 - val_accuracy: 0.9337
# Epoch 7/200
# 549/549 [==============================] - 2s 3ms/step - loss: 0.0056 - accuracy: 0.9350 - val_loss: 0.0055 - val_accuracy: 0.9357
# Epoch 8/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0051 - accuracy: 0.9387 - val_loss: 0.0055 - val_accuracy: 0.9348
# Epoch 9/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0048 - accuracy: 0.9369 - val_loss: 0.0055 - val_accuracy: 0.9378
# Epoch 10/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0045 - accuracy: 0.9399 - val_loss: 0.0049 - val_accuracy: 0.9367
# Epoch 11/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0042 - accuracy: 0.9418 - val_loss: 0.0045 - val_accuracy: 0.9437
# Epoch 12/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0040 - accuracy: 0.9435 - val_loss: 0.0044 - val_accuracy: 0.9405
# Epoch 13/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0039 - accuracy: 0.9431 - val_loss: 0.0041 - val_accuracy: 0.9387
# Epoch 14/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0037 - accuracy: 0.9451 - val_loss: 0.0041 - val_accuracy: 0.9408
# Epoch 15/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0035 - accuracy: 0.9450 - val_loss: 0.0039 - val_accuracy: 0.9442
# Epoch 16/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0034 - accuracy: 0.9459 - val_loss: 0.0039 - val_accuracy: 0.9469
# Epoch 17/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0034 - accuracy: 0.9462 - val_loss: 0.0037 - val_accuracy: 0.9476
# Epoch 18/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0032 - accuracy: 0.9482 - val_loss: 0.0036 - val_accuracy: 0.9446
# Epoch 19/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0031 - accuracy: 0.9490 - val_loss: 0.0034 - val_accuracy: 0.9474
# Epoch 20/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0031 - accuracy: 0.9493 - val_loss: 0.0035 - val_accuracy: 0.9481
# Epoch 21/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0030 - accuracy: 0.9521 - val_loss: 0.0039 - val_accuracy: 0.9467
# Epoch 22/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0029 - accuracy: 0.9495 - val_loss: 0.0038 - val_accuracy: 0.9458
# Epoch 23/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0028 - accuracy: 0.9514 - val_loss: 0.0036 - val_accuracy: 0.9508
# Epoch 24/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0028 - accuracy: 0.9508 - val_loss: 0.0032 - val_accuracy: 0.9526
# Epoch 25/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0028 - accuracy: 0.9529 - val_loss: 0.0034 - val_accuracy: 0.9515
# Epoch 26/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0026 - accuracy: 0.9544 - val_loss: 0.0031 - val_accuracy: 0.9485
# Epoch 27/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0027 - accuracy: 0.9535 - val_loss: 0.0036 - val_accuracy: 0.9542
# Epoch 28/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0026 - accuracy: 0.9523 - val_loss: 0.0035 - val_accuracy: 0.9508
# Epoch 29/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0025 - accuracy: 0.9532 - val_loss: 0.0032 - val_accuracy: 0.9540
# Epoch 30/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0024 - accuracy: 0.9532 - val_loss: 0.0034 - val_accuracy: 0.9476
# Epoch 31/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0025 - accuracy: 0.9544 - val_loss: 0.0033 - val_accuracy: 0.9471
# Epoch 32/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0024 - accuracy: 0.9540 - val_loss: 0.0032 - val_accuracy: 0.9503
# Epoch 33/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0024 - accuracy: 0.9533 - val_loss: 0.0030 - val_accuracy: 0.9512
# Epoch 34/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0024 - accuracy: 0.9544 - val_loss: 0.0030 - val_accuracy: 0.9542
# Epoch 35/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0023 - accuracy: 0.9552 - val_loss: 0.0029 - val_accuracy: 0.9512
# Epoch 36/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0023 - accuracy: 0.9539 - val_loss: 0.0027 - val_accuracy: 0.9542
# Epoch 37/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0023 - accuracy: 0.9551 - val_loss: 0.0028 - val_accuracy: 0.9526
# Epoch 38/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0022 - accuracy: 0.9563 - val_loss: 0.0032 - val_accuracy: 0.9524
# Epoch 39/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0022 - accuracy: 0.9557 - val_loss: 0.0027 - val_accuracy: 0.9574
# Epoch 40/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0021 - accuracy: 0.9568 - val_loss: 0.0029 - val_accuracy: 0.9560
# Epoch 41/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0021 - accuracy: 0.9555 - val_loss: 0.0029 - val_accuracy: 0.9560
# Epoch 42/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0021 - accuracy: 0.9566 - val_loss: 0.0029 - val_accuracy: 0.9549
# Epoch 43/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0021 - accuracy: 0.9562 - val_loss: 0.0027 - val_accuracy: 0.9551
# Epoch 44/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0021 - accuracy: 0.9572 - val_loss: 0.0030 - val_accuracy: 0.9572
# Epoch 45/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0021 - accuracy: 0.9584 - val_loss: 0.0027 - val_accuracy: 0.9567
# Epoch 46/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0020 - accuracy: 0.9572 - val_loss: 0.0026 - val_accuracy: 0.9588
# Epoch 47/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0021 - accuracy: 0.9578 - val_loss: 0.0026 - val_accuracy: 0.9569
# Epoch 48/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0020 - accuracy: 0.9588 - val_loss: 0.0025 - val_accuracy: 0.9565
# Epoch 49/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0020 - accuracy: 0.9591 - val_loss: 0.0032 - val_accuracy: 0.9567
# Epoch 50/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0020 - accuracy: 0.9585 - val_loss: 0.0026 - val_accuracy: 0.9581
# Epoch 51/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0020 - accuracy: 0.9592 - val_loss: 0.0028 - val_accuracy: 0.9531
# Epoch 52/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0019 - accuracy: 0.9583 - val_loss: 0.0030 - val_accuracy: 0.9551
# Epoch 53/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0020 - accuracy: 0.9586 - val_loss: 0.0025 - val_accuracy: 0.9578
# Epoch 54/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0019 - accuracy: 0.9589 - val_loss: 0.0025 - val_accuracy: 0.9594
# Epoch 55/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0018 - accuracy: 0.9610 - val_loss: 0.0024 - val_accuracy: 0.9585
# Epoch 56/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0019 - accuracy: 0.9613 - val_loss: 0.0024 - val_accuracy: 0.9558
# Epoch 57/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0018 - accuracy: 0.9606 - val_loss: 0.0025 - val_accuracy: 0.9601
# Epoch 58/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0019 - accuracy: 0.9594 - val_loss: 0.0029 - val_accuracy: 0.9594
# Epoch 59/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0018 - accuracy: 0.9599 - val_loss: 0.0024 - val_accuracy: 0.9592
# Epoch 60/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0018 - accuracy: 0.9612 - val_loss: 0.0025 - val_accuracy: 0.9599
# Epoch 61/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0018 - accuracy: 0.9608 - val_loss: 0.0024 - val_accuracy: 0.9601
# Epoch 62/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0018 - accuracy: 0.9602 - val_loss: 0.0023 - val_accuracy: 0.9601
# Epoch 63/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0018 - accuracy: 0.9618 - val_loss: 0.0023 - val_accuracy: 0.9610
# Epoch 64/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0018 - accuracy: 0.9604 - val_loss: 0.0024 - val_accuracy: 0.9597
# Epoch 65/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0018 - accuracy: 0.9613 - val_loss: 0.0024 - val_accuracy: 0.9585
# Epoch 66/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0018 - accuracy: 0.9616 - val_loss: 0.0023 - val_accuracy: 0.9617
# Epoch 67/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0017 - accuracy: 0.9618 - val_loss: 0.0028 - val_accuracy: 0.9565
# Epoch 68/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0017 - accuracy: 0.9611 - val_loss: 0.0024 - val_accuracy: 0.9588
# Epoch 69/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0018 - accuracy: 0.9603 - val_loss: 0.0023 - val_accuracy: 0.9631
# Epoch 70/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0017 - accuracy: 0.9626 - val_loss: 0.0024 - val_accuracy: 0.9583
# Epoch 71/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0017 - accuracy: 0.9625 - val_loss: 0.0028 - val_accuracy: 0.9574
# Epoch 72/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0017 - accuracy: 0.9626 - val_loss: 0.0025 - val_accuracy: 0.9604
# Epoch 73/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0017 - accuracy: 0.9629 - val_loss: 0.0023 - val_accuracy: 0.9576
# Epoch 74/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0017 - accuracy: 0.9618 - val_loss: 0.0022 - val_accuracy: 0.9604
# Epoch 75/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0017 - accuracy: 0.9618 - val_loss: 0.0023 - val_accuracy: 0.9597
# Epoch 76/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0017 - accuracy: 0.9623 - val_loss: 0.0023 - val_accuracy: 0.9606
# Epoch 77/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0016 - accuracy: 0.9619 - val_loss: 0.0024 - val_accuracy: 0.9620
# Epoch 78/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0017 - accuracy: 0.9620 - val_loss: 0.0023 - val_accuracy: 0.9594
# Epoch 79/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0016 - accuracy: 0.9619 - val_loss: 0.0023 - val_accuracy: 0.9610
# Epoch 80/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0016 - accuracy: 0.9627 - val_loss: 0.0024 - val_accuracy: 0.9585
# Epoch 81/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0016 - accuracy: 0.9621 - val_loss: 0.0023 - val_accuracy: 0.9585
# Epoch 82/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0016 - accuracy: 0.9621 - val_loss: 0.0023 - val_accuracy: 0.9581
# Epoch 83/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0016 - accuracy: 0.9616 - val_loss: 0.0025 - val_accuracy: 0.9551
# Epoch 84/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0016 - accuracy: 0.9629 - val_loss: 0.0023 - val_accuracy: 0.9572
# Epoch 85/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0016 - accuracy: 0.9631 - val_loss: 0.0022 - val_accuracy: 0.9574
# Epoch 86/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0016 - accuracy: 0.9622 - val_loss: 0.0021 - val_accuracy: 0.9585
# Epoch 87/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0016 - accuracy: 0.9625 - val_loss: 0.0024 - val_accuracy: 0.9590
# Epoch 88/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0016 - accuracy: 0.9623 - val_loss: 0.0023 - val_accuracy: 0.9592
# Epoch 89/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0016 - accuracy: 0.9606 - val_loss: 0.0025 - val_accuracy: 0.9594
# Epoch 90/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0016 - accuracy: 0.9625 - val_loss: 0.0023 - val_accuracy: 0.9574
# Epoch 91/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0015 - accuracy: 0.9626 - val_loss: 0.0023 - val_accuracy: 0.9599
# Epoch 92/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0016 - accuracy: 0.9622 - val_loss: 0.0022 - val_accuracy: 0.9592
# Epoch 93/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0015 - accuracy: 0.9622 - val_loss: 0.0023 - val_accuracy: 0.9563
# Epoch 94/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0015 - accuracy: 0.9629 - val_loss: 0.0023 - val_accuracy: 0.9601
# Epoch 95/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0015 - accuracy: 0.9613 - val_loss: 0.0021 - val_accuracy: 0.9578
# Epoch 96/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0015 - accuracy: 0.9627 - val_loss: 0.0022 - val_accuracy: 0.9617
# Epoch 97/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0015 - accuracy: 0.9627 - val_loss: 0.0023 - val_accuracy: 0.9592
# Epoch 98/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0015 - accuracy: 0.9620 - val_loss: 0.0022 - val_accuracy: 0.9617
# Epoch 99/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0015 - accuracy: 0.9620 - val_loss: 0.0023 - val_accuracy: 0.9599
# Epoch 100/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0015 - accuracy: 0.9621 - val_loss: 0.0027 - val_accuracy: 0.9565
# Epoch 101/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0015 - accuracy: 0.9624 - val_loss: 0.0023 - val_accuracy: 0.9576
# Epoch 102/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0015 - accuracy: 0.9614 - val_loss: 0.0022 - val_accuracy: 0.9592
# Epoch 103/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0015 - accuracy: 0.9621 - val_loss: 0.0023 - val_accuracy: 0.9569
# Epoch 104/200
# 549/549 [==============================] - 1s 3ms/step - loss: 0.0015 - accuracy: 0.9618 - val_loss: 0.0025 - val_accuracy: 0.9594
# Epoch 105/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0015 - accuracy: 0.9621 - val_loss: 0.0022 - val_accuracy: 0.9565
# Epoch 106/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0014 - accuracy: 0.9632 - val_loss: 0.0022 - val_accuracy: 0.9608
# Epoch 107/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0015 - accuracy: 0.9610 - val_loss: 0.0021 - val_accuracy: 0.9588
# Epoch 108/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0014 - accuracy: 0.9627 - val_loss: 0.0021 - val_accuracy: 0.9585
# Epoch 109/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0015 - accuracy: 0.9625 - val_loss: 0.0021 - val_accuracy: 0.9620
# Epoch 110/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0014 - accuracy: 0.9629 - val_loss: 0.0025 - val_accuracy: 0.9576
# Epoch 111/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0015 - accuracy: 0.9624 - val_loss: 0.0021 - val_accuracy: 0.9597
# Epoch 112/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0014 - accuracy: 0.9638 - val_loss: 0.0022 - val_accuracy: 0.9610
# Epoch 113/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0014 - accuracy: 0.9624 - val_loss: 0.0022 - val_accuracy: 0.9606
# Epoch 114/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0014 - accuracy: 0.9621 - val_loss: 0.0020 - val_accuracy: 0.9624
# Epoch 115/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0014 - accuracy: 0.9635 - val_loss: 0.0021 - val_accuracy: 0.9631
# Epoch 116/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0014 - accuracy: 0.9629 - val_loss: 0.0021 - val_accuracy: 0.9615
# Epoch 117/200
# 549/549 [==============================] - 1s 3ms/step - loss: 0.0014 - accuracy: 0.9638 - val_loss: 0.0021 - val_accuracy: 0.9622
# Epoch 118/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0014 - accuracy: 0.9640 - val_loss: 0.0021 - val_accuracy: 0.9626
# Epoch 119/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0014 - accuracy: 0.9621 - val_loss: 0.0021 - val_accuracy: 0.9590
# Epoch 120/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0014 - accuracy: 0.9618 - val_loss: 0.0020 - val_accuracy: 0.9590
# Epoch 121/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0014 - accuracy: 0.9626 - val_loss: 0.0023 - val_accuracy: 0.9599
# Epoch 122/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0014 - accuracy: 0.9641 - val_loss: 0.0025 - val_accuracy: 0.9547
# Epoch 123/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0014 - accuracy: 0.9614 - val_loss: 0.0023 - val_accuracy: 0.9560
# Epoch 124/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0014 - accuracy: 0.9617 - val_loss: 0.0022 - val_accuracy: 0.9617
# Epoch 125/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0014 - accuracy: 0.9635 - val_loss: 0.0020 - val_accuracy: 0.9638
# Epoch 126/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0014 - accuracy: 0.9618 - val_loss: 0.0020 - val_accuracy: 0.9640
# Epoch 127/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0014 - accuracy: 0.9626 - val_loss: 0.0020 - val_accuracy: 0.9597
# Epoch 128/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0014 - accuracy: 0.9629 - val_loss: 0.0024 - val_accuracy: 0.9576
# Epoch 129/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0014 - accuracy: 0.9633 - val_loss: 0.0021 - val_accuracy: 0.9608
# Epoch 130/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0014 - accuracy: 0.9623 - val_loss: 0.0020 - val_accuracy: 0.9640
# Epoch 131/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0014 - accuracy: 0.9622 - val_loss: 0.0022 - val_accuracy: 0.9585
# Epoch 132/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0014 - accuracy: 0.9620 - val_loss: 0.0024 - val_accuracy: 0.9585
# Epoch 133/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0014 - accuracy: 0.9615 - val_loss: 0.0020 - val_accuracy: 0.9613
# Epoch 134/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0013 - accuracy: 0.9625 - val_loss: 0.0022 - val_accuracy: 0.9633
# Epoch 135/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0014 - accuracy: 0.9616 - val_loss: 0.0021 - val_accuracy: 0.9601
# Epoch 136/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0013 - accuracy: 0.9622 - val_loss: 0.0021 - val_accuracy: 0.9604
# Epoch 137/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0014 - accuracy: 0.9640 - val_loss: 0.0021 - val_accuracy: 0.9599
# Epoch 138/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0013 - accuracy: 0.9625 - val_loss: 0.0021 - val_accuracy: 0.9590
# Epoch 139/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0013 - accuracy: 0.9631 - val_loss: 0.0020 - val_accuracy: 0.9599
# Epoch 140/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0013 - accuracy: 0.9631 - val_loss: 0.0022 - val_accuracy: 0.9631
# Epoch 141/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0013 - accuracy: 0.9634 - val_loss: 0.0020 - val_accuracy: 0.9626
# Epoch 142/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0013 - accuracy: 0.9642 - val_loss: 0.0019 - val_accuracy: 0.9640
# Epoch 143/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0013 - accuracy: 0.9623 - val_loss: 0.0021 - val_accuracy: 0.9617
# Epoch 144/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0013 - accuracy: 0.9631 - val_loss: 0.0021 - val_accuracy: 0.9592
# Epoch 145/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0013 - accuracy: 0.9631 - val_loss: 0.0020 - val_accuracy: 0.9626
# Epoch 146/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0013 - accuracy: 0.9643 - val_loss: 0.0020 - val_accuracy: 0.9633
# Epoch 147/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0013 - accuracy: 0.9634 - val_loss: 0.0023 - val_accuracy: 0.9581
# Epoch 148/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0013 - accuracy: 0.9629 - val_loss: 0.0020 - val_accuracy: 0.9638
# Epoch 149/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0013 - accuracy: 0.9638 - val_loss: 0.0023 - val_accuracy: 0.9606
# Epoch 150/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0013 - accuracy: 0.9641 - val_loss: 0.0021 - val_accuracy: 0.9608
# Epoch 151/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0013 - accuracy: 0.9636 - val_loss: 0.0020 - val_accuracy: 0.9642
# Epoch 152/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0013 - accuracy: 0.9633 - val_loss: 0.0019 - val_accuracy: 0.9640
# Epoch 153/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0013 - accuracy: 0.9631 - val_loss: 0.0019 - val_accuracy: 0.9645
# Epoch 154/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0013 - accuracy: 0.9645 - val_loss: 0.0020 - val_accuracy: 0.9594
# Epoch 155/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0013 - accuracy: 0.9649 - val_loss: 0.0020 - val_accuracy: 0.9647
# Epoch 156/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0013 - accuracy: 0.9651 - val_loss: 0.0020 - val_accuracy: 0.9626
# Epoch 157/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0013 - accuracy: 0.9640 - val_loss: 0.0019 - val_accuracy: 0.9588
# Epoch 158/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0013 - accuracy: 0.9651 - val_loss: 0.0019 - val_accuracy: 0.9633
# Epoch 159/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0013 - accuracy: 0.9639 - val_loss: 0.0021 - val_accuracy: 0.9606
# Epoch 160/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0013 - accuracy: 0.9630 - val_loss: 0.0020 - val_accuracy: 0.9576
# Epoch 161/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0012 - accuracy: 0.9637 - val_loss: 0.0020 - val_accuracy: 0.9620
# Epoch 162/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0012 - accuracy: 0.9638 - val_loss: 0.0019 - val_accuracy: 0.9665
# Epoch 163/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0013 - accuracy: 0.9639 - val_loss: 0.0021 - val_accuracy: 0.9631
# Epoch 164/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0012 - accuracy: 0.9650 - val_loss: 0.0019 - val_accuracy: 0.9640
# Epoch 165/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0013 - accuracy: 0.9647 - val_loss: 0.0021 - val_accuracy: 0.9629
# Epoch 166/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0012 - accuracy: 0.9652 - val_loss: 0.0019 - val_accuracy: 0.9601
# Epoch 167/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0013 - accuracy: 0.9637 - val_loss: 0.0020 - val_accuracy: 0.9617
# Epoch 168/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0013 - accuracy: 0.9629 - val_loss: 0.0020 - val_accuracy: 0.9642
# Epoch 169/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0012 - accuracy: 0.9647 - val_loss: 0.0020 - val_accuracy: 0.9604
# Epoch 170/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0013 - accuracy: 0.9643 - val_loss: 0.0021 - val_accuracy: 0.9581
# Epoch 171/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0013 - accuracy: 0.9649 - val_loss: 0.0019 - val_accuracy: 0.9649
# Epoch 172/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0012 - accuracy: 0.9654 - val_loss: 0.0022 - val_accuracy: 0.9633
# Epoch 173/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0012 - accuracy: 0.9641 - val_loss: 0.0019 - val_accuracy: 0.9674
# Epoch 174/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0012 - accuracy: 0.9648 - val_loss: 0.0019 - val_accuracy: 0.9631
# Epoch 175/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0012 - accuracy: 0.9650 - val_loss: 0.0021 - val_accuracy: 0.9635
# Epoch 176/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0012 - accuracy: 0.9651 - val_loss: 0.0018 - val_accuracy: 0.9665
# Epoch 177/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0012 - accuracy: 0.9650 - val_loss: 0.0020 - val_accuracy: 0.9629
# Epoch 178/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0012 - accuracy: 0.9647 - val_loss: 0.0019 - val_accuracy: 0.9606
# Epoch 179/200
# 549/549 [==============================] - 1s 3ms/step - loss: 0.0012 - accuracy: 0.9646 - val_loss: 0.0018 - val_accuracy: 0.9629
# Epoch 180/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0012 - accuracy: 0.9644 - val_loss: 0.0020 - val_accuracy: 0.9629
# Epoch 181/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0012 - accuracy: 0.9640 - val_loss: 0.0022 - val_accuracy: 0.9626
# Epoch 182/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0012 - accuracy: 0.9651 - val_loss: 0.0019 - val_accuracy: 0.9617
# Epoch 183/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0012 - accuracy: 0.9649 - val_loss: 0.0019 - val_accuracy: 0.9622
# Epoch 184/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0012 - accuracy: 0.9651 - val_loss: 0.0018 - val_accuracy: 0.9638
# Epoch 185/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0012 - accuracy: 0.9647 - val_loss: 0.0018 - val_accuracy: 0.9640
# Epoch 186/200
# 549/549 [==============================] - 1s 3ms/step - loss: 0.0012 - accuracy: 0.9646 - val_loss: 0.0019 - val_accuracy: 0.9649
# Epoch 187/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0012 - accuracy: 0.9642 - val_loss: 0.0023 - val_accuracy: 0.9613
# Epoch 188/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0012 - accuracy: 0.9646 - val_loss: 0.0019 - val_accuracy: 0.9610
# Epoch 189/200
# 549/549 [==============================] - 1s 3ms/step - loss: 0.0012 - accuracy: 0.9650 - val_loss: 0.0019 - val_accuracy: 0.9638
# Epoch 190/200
# 549/549 [==============================] - 1s 3ms/step - loss: 0.0012 - accuracy: 0.9651 - val_loss: 0.0019 - val_accuracy: 0.9624
# Epoch 191/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0012 - accuracy: 0.9656 - val_loss: 0.0020 - val_accuracy: 0.9638
# Epoch 192/200
# 549/549 [==============================] - 1s 3ms/step - loss: 0.0012 - accuracy: 0.9660 - val_loss: 0.0018 - val_accuracy: 0.9681
# Epoch 193/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0012 - accuracy: 0.9654 - val_loss: 0.0019 - val_accuracy: 0.9647
# Epoch 194/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0012 - accuracy: 0.9652 - val_loss: 0.0020 - val_accuracy: 0.9635
# Epoch 195/200
# 549/549 [==============================] - 1s 3ms/step - loss: 0.0012 - accuracy: 0.9638 - val_loss: 0.0018 - val_accuracy: 0.9581
# Epoch 196/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0012 - accuracy: 0.9646 - val_loss: 0.0020 - val_accuracy: 0.9654
# Epoch 197/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0012 - accuracy: 0.9653 - val_loss: 0.0018 - val_accuracy: 0.9656
# Epoch 198/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0012 - accuracy: 0.9658 - val_loss: 0.0018 - val_accuracy: 0.9665
# Epoch 199/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0012 - accuracy: 0.9653 - val_loss: 0.0018 - val_accuracy: 0.9640
# Epoch 200/200
# 549/549 [==============================] - 1s 2ms/step - loss: 0.0012 - accuracy: 0.9647 - val_loss: 0.0021 - val_accuracy: 0.9654

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('loss function')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %% [markdown]
# #Training (Hesham's model)

# %%
###Hesham's sequential model - use one or the other ####

import tensorflow as tf

# Instantiate a sequential model
modelANN = tf.keras.models.Sequential()
n_cols = X_scaled.shape[1]  

# model architecture
modelANN.add(tf.keras.layers.Dense(10, input_shape=(n_cols,), activation='sigmoid'))# INPUT LAYER

modelANN.add(tf.keras.layers.Dense(18, activation='relu'))
modelANN.add(tf.keras.layers.Dense(52, activation='relu'))
modelANN.add(tf.keras.layers.Dense(27, activation='relu'))
modelANN.add(tf.keras.layers.Dense(18, activation='relu'))


 
# Add a dense layer with 1 value output
modelANN.add(tf.keras.layers.Dense(3, activation= "sigmoid")) # OUTPUT LAYER
  
# Compile the model model 
modelANN.compile(optimizer = "adam", loss = "mean_squared_error", metrics = ["accuracy"])

modelANN.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 10)                290
#
#  dense_5 (Dense)             (None, 18)                198
#
#  dense_6 (Dense)             (None, 52)                988
#
#  dense_7 (Dense)             (None, 27)                1431
#
#  dense_8 (Dense)             (None, 18)                504
#
#  dense_9 (Dense)             (None, 3)                 57
#
# =================================================================
# Total params: 3,468
# Trainable params: 3,468
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # MODEL SAVING

# %%
#https://www.tensorflow.org/guide/keras/save_and_serialize
modelANN.save("ANNModel.h5")

scalerX_filename = "scalerX_save"
joblib.dump(scalerX, scalerX_filename)

scalerY_filename = "scalerY_save"
joblib.dump(scalerY, scalerY_filename)
# Out:
# ['scalerY_save']

# %% [markdown]
# # HOPS

# %%
y.head()
# Out:
#       sDA        UDI    ASE
# 0   40.80  79.145797   5.82
# 1   22.73  39.574263   4.76
# 2  100.00  47.284580  57.77
# 3    0.00  47.657260   0.00
# 4  100.00  63.463152  42.63

# %%
# 1 --- import model

path = "/content/ANNModel.h5"
model = tf.keras.models.load_model(path)
model = modelANN
# 2 --- set up scaler variables

scalerX = joblib.load("/content/scalerX_save")
scalerY = joblib.load("/content/scalerY_save")


def myMLPredictions(FloorHeight, Width, Length, Rotation, SouthContextOffset, EastContextOffset, NorthContextOffset, WestContextOffset, SouthContextHeight, EastContextHeight, NorthContextHeight, 
                          WestContextHeight, SouthShadingDepth, EastShadingDepth, NorthShadingDepth, WestShadingDepth, NorthGlazingRatio, WestGlazingRatio, SouthGlazingRatio, EastGlazingRatio, 
                          NorthWindowHeight, WestWindowHeight, SouthWindowHeight, EastWindowHeight, NorthWindowSill, WestWindowSill, SouthWindowSill, EastWindowSill, Location):

    # Create Input Array
    new_data = pd.DataFrame([[FloorHeight, Width, Length, Rotation, SouthContextOffset, EastContextOffset, NorthContextOffset, WestContextOffset, SouthContextHeight, EastContextHeight, NorthContextHeight, 
                          WestContextHeight, SouthShadingDepth, EastShadingDepth, NorthShadingDepth, WestShadingDepth, NorthGlazingRatio, WestGlazingRatio, SouthGlazingRatio, EastGlazingRatio, 
                          NorthWindowHeight, WestWindowHeight, SouthWindowHeight, EastWindowHeight, NorthWindowSill, WestWindowSill, SouthWindowSill, EastWindowSill, Location]])

    # Scale Input to match the same format from the trained model
    scaled_input = scalerX.transform(new_data)

    # Generate Predictions from Scaled Input using model.predict
    #https://www.tensorflow.org/api_docs/python/tf/keras/Model

    # 01// predict
    out = model.predict(scaled_input)
    #02 // inverse scaling
    predictions = scalerY.inverse_transform(out)

    
    #Flatten predictions list to be readable for hops
    pred_list = predictions.tolist()
    flat_list = []

    for i in pred_list:
        flat_list += i
    

    # Set each prediction value to a variable
    sDA= flat_list[0]
    UDI= flat_list[1]
    ASE= flat_list[2]

    return sDA, UDI, ASE

# %%
x.head()
# Out:
#    FloorHeight      Width  Length  Rotation  SouthContextOffset  \
# 0          8.0  31.666667    14.0     -22.0                  69
# 1          8.0  31.666667    14.0     -22.0                  69
# 2          8.0  31.666667    14.0     -22.0                  69
# 3          8.0  31.666667    14.0     -22.0                  69
# 4          8.0  31.666667    14.0     -22.0                  69
#
#    EastContextOffset  NorthContextOffset  WestContextOffset  \
# 0                 12                  11                 71
# 1                 12                  11                 71
# 2                 12                  11                 71
# 3                 12                  11                 71
# 4                 12                  11                 71
#
#    SouthContextHeight  EastContextHeight  NorthContextHeight  \
# 0                 161                125                 472
# 1                 161                125                 472
# 2                 161                125                 472
# 3                 161                125                 472
# 4                 161                125                 472
#
#    WestContextHeight  SouthShadingDepth  EastShadingDepth  NorthShadingDepth  \
# 0                142               1.96               1.4               1.93
# 1                142               1.96               1.4               1.93
# 2                142               1.96               1.4               1.93
# 3                142               1.96               1.4               1.93
# 4                142               1.96               1.4               1.93
#
#    WestShadingDepth  NorthGlazingRatio  WestGlazingRatio  SouthGlazingRatio  \
# 0              2.11                0.2               0.3                0.0
# 1              2.11                0.0               0.3                0.0
# 2              2.11                0.0               0.3                0.7
# 3              2.11                0.2               0.0                0.0
# 4              2.11                0.0               0.0                0.7
#
#    EastGlazingRatio  NorthWindowHeight  WestWindowHeight  SouthWindowHeight  \
# 0               0.0                  0                 4                  6
# 1               0.0                  0                 4                  6
# 2               0.0                  0                 4                  6
# 3               0.0                  0                 4                  6
# 4               0.0                  0                 4                  6
#
#    EastWindowHeight  NorthWindowSill  WestWindowSill  SouthWindowSill  \
# 0                 8                5               1                0
# 1                 8                5               1                0
# 2                 8                5               1                0
# 3                 8                5               1                0
# 4                 8                5               1                0
#
#    EastWindowSill  Location
# 0               2         1
# 1               2         1
# 2               2         1
# 3               2         1
# 4               2         1

# %%
app = Flask(__name__)
#using ngrok library to stream data
run_with_ngrok(app) 
hops = hs.Hops(app)

# -- ATOB MODEL

@hops.component(
    "/hello3",
    name="Daylight Predictor",
    description="Daylight Predictor with machine learning",
    inputs=[
        hs.HopsNumber("FloorHeight", "H", "Floor Height"),
        hs.HopsNumber("Width", "W", "Width"),
        hs.HopsNumber("Length", "L", "Length"),
        hs.HopsNumber("Rotation", "R", "Building Rotation"),
        hs.HopsNumber("SouthContextOffset", "SCO", "South Context Offset"),
        hs.HopsNumber("EastContextOffset", "ECO", "East Context Offset"),
        hs.HopsNumber("NorthContextOffset", "NCO", "North Context Offset"),
        hs.HopsNumber("WestContextOffset", "WCO", "West Context Offset"),
        hs.HopsNumber("SouthContextHeight", "SCH", "South Context Height"),
        hs.HopsNumber("EastContextHeight", "ECH", "East Context Height"),
        hs.HopsNumber("NorthContextHeight", "NCH", "North Context Height"),
        hs.HopsNumber("WestContextHeight", "WCH", "WestContextHeight"),
        hs.HopsNumber("SouthShadingDepth", "SSD", "South Shading Depth"),
        hs.HopsNumber("EastShadingDepth", "ESD", "East Shading Depth"),
        hs.HopsNumber("NorthShadingDepth", "NSD", "North Shading Depth"),
        hs.HopsNumber("WestShadingDepth", "WSD", "West Shading Depth"),
        hs.HopsNumber("NorthGlazingRatio", "NGR", "North Glazing Ratio"),
        hs.HopsNumber("WestGlazingRatio", "WGR", "West Glazing Ratio"),
        hs.HopsNumber("SouthGlazingRatio", "SGR", "South Glazing Ratio"),
        hs.HopsNumber("EastGlazingRatio", "EGR", "East Glazing Ratio"),
        hs.HopsNumber("NorthWindowHeight", "NWH", "North Window Height"),
        hs.HopsNumber("WestWindowHeight", "WWH", "West Window Height"),
        hs.HopsNumber("SouthWindowHeight", "SWH", "South Window Height"),
        hs.HopsNumber("EastWindowHeight", "EWH", "East Window Height"),
        hs.HopsNumber("NorthWindowSill", "NWS", "North Window Sill"),
        hs.HopsNumber("WestWindowSill", "WWS", "West Window Sill"),
        hs.HopsNumber("SouthWindowSill", "SWS", "South Window Sill"),
        hs.HopsNumber("EastWindowSill", "EWS", "East Window Sill"),
        hs.HopsNumber("Location", "LO", "Location")
    ],
    outputs=[
        hs.HopsNumber("sDA", "sDA", "Spatial Daylight Autonomy"),
        hs.HopsNumber("UDI", "UDI", "Useful Daylight Illuminance"),
        hs.HopsNumber("ASE", "ASE", "Annual Sun Exposure")
    ]
)

def myMLFunction(FloorHeight, Width, Length, Rotation, SouthContextOffset, EastContextOffset, NorthContextOffset, WestContextOffset, SouthContextHeight, EastContextHeight, NorthContextHeight, 
                          WestContextHeight, SouthShadingDepth, EastShadingDepth, NorthShadingDepth, WestShadingDepth, NorthGlazingRatio, WestGlazingRatio, SouthGlazingRatio, EastGlazingRatio, 
                          NorthWindowHeight, WestWindowHeight, SouthWindowHeight, EastWindowHeight, NorthWindowSill, WestWindowSill, SouthWindowSill, EastWindowSill, Location):
    return myMLPredictions(FloorHeight, Width, Length, Rotation, SouthContextOffset, EastContextOffset, NorthContextOffset, WestContextOffset, SouthContextHeight, EastContextHeight, NorthContextHeight, 
                          WestContextHeight, SouthShadingDepth, EastShadingDepth, NorthShadingDepth, WestShadingDepth, NorthGlazingRatio, WestGlazingRatio, SouthGlazingRatio, EastGlazingRatio, 
                          NorthWindowHeight, WestWindowHeight, SouthWindowHeight, EastWindowHeight, NorthWindowSill, WestWindowSill, SouthWindowSill, EastWindowSill, Location)

# %%
#run the app
app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
# INFO:werkzeug: * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
#  * Running on http://7fad-34-125-238-235.ngrok.io
#  * Traffic stats available on http://127.0.0.1:4040
# INFO:werkzeug:127.0.0.1 - - [08/Sep/2022 20:42:47] "GET /hello3 HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [08/Sep/2022 20:42:48] "GET /hello3 HTTP/1.1" 200 -
# INFO:Hops:Solving using legacy API: <HopsComponent /hello3 [FloorHeight,Width,Length,Rotation,SouthContextOffset,EastContextOffset,NorthContextOffset,WestContextOffset,SouthContextHeight,EastContextHeight,NorthContextHeight,WestContextHeight,SouthShadingDepth,EastShadingDepth,NorthShadingDepth,WestShadingDepth,NorthGlazingRatio,WestGlazingRatio,SouthGlazingRatio,EastGlazingRatio,NorthWindowHeight,WestWindowHeight,SouthWindowHeight,EastWindowHeight,NorthWindowSill,WestWindowSill,SouthWindowSill,EastWindowSill,Location -> Daylight Predictor -> sDA,UDI,ASE] >
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   "X does not have valid feature names, but"
# INFO:werkzeug:127.0.0.1 - - [08/Sep/2022 20:42:53] "POST /solve HTTP/1.1" 200 -
# INFO:Hops:Solving using legacy API: <HopsComponent /hello3 [FloorHeight,Width,Length,Rotation,SouthContextOffset,EastContextOffset,NorthContextOffset,WestContextOffset,SouthContextHeight,EastContextHeight,NorthContextHeight,WestContextHeight,SouthShadingDepth,EastShadingDepth,NorthShadingDepth,WestShadingDepth,NorthGlazingRatio,WestGlazingRatio,SouthGlazingRatio,EastGlazingRatio,NorthWindowHeight,WestWindowHeight,SouthWindowHeight,EastWindowHeight,NorthWindowSill,WestWindowSill,SouthWindowSill,EastWindowSill,Location -> Daylight Predictor -> sDA,UDI,ASE] >
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   "X does not have valid feature names, but"
# INFO:werkzeug:127.0.0.1 - - [08/Sep/2022 20:44:54] "POST /solve HTTP/1.1" 200 -
# INFO:Hops:Solving using legacy API: <HopsComponent /hello3 [FloorHeight,Width,Length,Rotation,SouthContextOffset,EastContextOffset,NorthContextOffset,WestContextOffset,SouthContextHeight,EastContextHeight,NorthContextHeight,WestContextHeight,SouthShadingDepth,EastShadingDepth,NorthShadingDepth,WestShadingDepth,NorthGlazingRatio,WestGlazingRatio,SouthGlazingRatio,EastGlazingRatio,NorthWindowHeight,WestWindowHeight,SouthWindowHeight,EastWindowHeight,NorthWindowSill,WestWindowSill,SouthWindowSill,EastWindowSill,Location -> Daylight Predictor -> sDA,UDI,ASE] >
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   "X does not have valid feature names, but"
# INFO:werkzeug:127.0.0.1 - - [08/Sep/2022 20:44:57] "POST /solve HTTP/1.1" 200 -
# INFO:Hops:Solving using legacy API: <HopsComponent /hello3 [FloorHeight,Width,Length,Rotation,SouthContextOffset,EastContextOffset,NorthContextOffset,WestContextOffset,SouthContextHeight,EastContextHeight,NorthContextHeight,WestContextHeight,SouthShadingDepth,EastShadingDepth,NorthShadingDepth,WestShadingDepth,NorthGlazingRatio,WestGlazingRatio,SouthGlazingRatio,EastGlazingRatio,NorthWindowHeight,WestWindowHeight,SouthWindowHeight,EastWindowHeight,NorthWindowSill,WestWindowSill,SouthWindowSill,EastWindowSill,Location -> Daylight Predictor -> sDA,UDI,ASE] >
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   "X does not have valid feature names, but"
# INFO:werkzeug:127.0.0.1 - - [08/Sep/2022 20:47:28] "POST /solve HTTP/1.1" 200 -
# INFO:Hops:Solving using legacy API: <HopsComponent /hello3 [FloorHeight,Width,Length,Rotation,SouthContextOffset,EastContextOffset,NorthContextOffset,WestContextOffset,SouthContextHeight,EastContextHeight,NorthContextHeight,WestContextHeight,SouthShadingDepth,EastShadingDepth,NorthShadingDepth,WestShadingDepth,NorthGlazingRatio,WestGlazingRatio,SouthGlazingRatio,EastGlazingRatio,NorthWindowHeight,WestWindowHeight,SouthWindowHeight,EastWindowHeight,NorthWindowSill,WestWindowSill,SouthWindowSill,EastWindowSill,Location -> Daylight Predictor -> sDA,UDI,ASE] >
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   "X does not have valid feature names, but"
# INFO:werkzeug:127.0.0.1 - - [08/Sep/2022 20:50:54] "POST /solve HTTP/1.1" 200 -
# INFO:Hops:Solving using legacy API: <HopsComponent /hello3 [FloorHeight,Width,Length,Rotation,SouthContextOffset,EastContextOffset,NorthContextOffset,WestContextOffset,SouthContextHeight,EastContextHeight,NorthContextHeight,WestContextHeight,SouthShadingDepth,EastShadingDepth,NorthShadingDepth,WestShadingDepth,NorthGlazingRatio,WestGlazingRatio,SouthGlazingRatio,EastGlazingRatio,NorthWindowHeight,WestWindowHeight,SouthWindowHeight,EastWindowHeight,NorthWindowSill,WestWindowSill,SouthWindowSill,EastWindowSill,Location -> Daylight Predictor -> sDA,UDI,ASE] >
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   "X does not have valid feature names, but"
# INFO:werkzeug:127.0.0.1 - - [08/Sep/2022 20:50:59] "POST /solve HTTP/1.1" 200 -
# INFO:Hops:Solving using legacy API: <HopsComponent /hello3 [FloorHeight,Width,Length,Rotation,SouthContextOffset,EastContextOffset,NorthContextOffset,WestContextOffset,SouthContextHeight,EastContextHeight,NorthContextHeight,WestContextHeight,SouthShadingDepth,EastShadingDepth,NorthShadingDepth,WestShadingDepth,NorthGlazingRatio,WestGlazingRatio,SouthGlazingRatio,EastGlazingRatio,NorthWindowHeight,WestWindowHeight,SouthWindowHeight,EastWindowHeight,NorthWindowSill,WestWindowSill,SouthWindowSill,EastWindowSill,Location -> Daylight Predictor -> sDA,UDI,ASE] >
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   "X does not have valid feature names, but"
# INFO:werkzeug:127.0.0.1 - - [08/Sep/2022 20:52:33] "POST /solve HTTP/1.1" 200 -
# INFO:Hops:Solving using legacy API: <HopsComponent /hello3 [FloorHeight,Width,Length,Rotation,SouthContextOffset,EastContextOffset,NorthContextOffset,WestContextOffset,SouthContextHeight,EastContextHeight,NorthContextHeight,WestContextHeight,SouthShadingDepth,EastShadingDepth,NorthShadingDepth,WestShadingDepth,NorthGlazingRatio,WestGlazingRatio,SouthGlazingRatio,EastGlazingRatio,NorthWindowHeight,WestWindowHeight,SouthWindowHeight,EastWindowHeight,NorthWindowSill,WestWindowSill,SouthWindowSill,EastWindowSill,Location -> Daylight Predictor -> sDA,UDI,ASE] >
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   "X does not have valid feature names, but"
# INFO:werkzeug:127.0.0.1 - - [08/Sep/2022 20:52:51] "POST /solve HTTP/1.1" 200 -
# INFO:Hops:Solving using legacy API: <HopsComponent /hello3 [FloorHeight,Width,Length,Rotation,SouthContextOffset,EastContextOffset,NorthContextOffset,WestContextOffset,SouthContextHeight,EastContextHeight,NorthContextHeight,WestContextHeight,SouthShadingDepth,EastShadingDepth,NorthShadingDepth,WestShadingDepth,NorthGlazingRatio,WestGlazingRatio,SouthGlazingRatio,EastGlazingRatio,NorthWindowHeight,WestWindowHeight,SouthWindowHeight,EastWindowHeight,NorthWindowSill,WestWindowSill,SouthWindowSill,EastWindowSill,Location -> Daylight Predictor -> sDA,UDI,ASE] >
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   "X does not have valid feature names, but"
# INFO:werkzeug:127.0.0.1 - - [08/Sep/2022 20:53:21] "POST /solve HTTP/1.1" 200 -
# INFO:Hops:Solving using legacy API: <HopsComponent /hello3 [FloorHeight,Width,Length,Rotation,SouthContextOffset,EastContextOffset,NorthContextOffset,WestContextOffset,SouthContextHeight,EastContextHeight,NorthContextHeight,WestContextHeight,SouthShadingDepth,EastShadingDepth,NorthShadingDepth,WestShadingDepth,NorthGlazingRatio,WestGlazingRatio,SouthGlazingRatio,EastGlazingRatio,NorthWindowHeight,WestWindowHeight,SouthWindowHeight,EastWindowHeight,NorthWindowSill,WestWindowSill,SouthWindowSill,EastWindowSill,Location -> Daylight Predictor -> sDA,UDI,ASE] >
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   "X does not have valid feature names, but"
# INFO:werkzeug:127.0.0.1 - - [08/Sep/2022 20:57:15] "POST /solve HTTP/1.1" 200 -
# INFO:Hops:Solving using legacy API: <HopsComponent /hello3 [FloorHeight,Width,Length,Rotation,SouthContextOffset,EastContextOffset,NorthContextOffset,WestContextOffset,SouthContextHeight,EastContextHeight,NorthContextHeight,WestContextHeight,SouthShadingDepth,EastShadingDepth,NorthShadingDepth,WestShadingDepth,NorthGlazingRatio,WestGlazingRatio,SouthGlazingRatio,EastGlazingRatio,NorthWindowHeight,WestWindowHeight,SouthWindowHeight,EastWindowHeight,NorthWindowSill,WestWindowSill,SouthWindowSill,EastWindowSill,Location -> Daylight Predictor -> sDA,UDI,ASE] >
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   "X does not have valid feature names, but"
# INFO:werkzeug:127.0.0.1 - - [08/Sep/2022 20:57:22] "POST /solve HTTP/1.1" 200 -
# INFO:Hops:Solving using legacy API: <HopsComponent /hello3 [FloorHeight,Width,Length,Rotation,SouthContextOffset,EastContextOffset,NorthContextOffset,WestContextOffset,SouthContextHeight,EastContextHeight,NorthContextHeight,WestContextHeight,SouthShadingDepth,EastShadingDepth,NorthShadingDepth,WestShadingDepth,NorthGlazingRatio,WestGlazingRatio,SouthGlazingRatio,EastGlazingRatio,NorthWindowHeight,WestWindowHeight,SouthWindowHeight,EastWindowHeight,NorthWindowSill,WestWindowSill,SouthWindowSill,EastWindowSill,Location -> Daylight Predictor -> sDA,UDI,ASE] >
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   "X does not have valid feature names, but"
# INFO:werkzeug:127.0.0.1 - - [08/Sep/2022 21:00:41] "POST /solve HTTP/1.1" 200 -
# INFO:Hops:Solving using legacy API: <HopsComponent /hello3 [FloorHeight,Width,Length,Rotation,SouthContextOffset,EastContextOffset,NorthContextOffset,WestContextOffset,SouthContextHeight,EastContextHeight,NorthContextHeight,WestContextHeight,SouthShadingDepth,EastShadingDepth,NorthShadingDepth,WestShadingDepth,NorthGlazingRatio,WestGlazingRatio,SouthGlazingRatio,EastGlazingRatio,NorthWindowHeight,WestWindowHeight,SouthWindowHeight,EastWindowHeight,NorthWindowSill,WestWindowSill,SouthWindowSill,EastWindowSill,Location -> Daylight Predictor -> sDA,UDI,ASE] >
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   "X does not have valid feature names, but"
# INFO:werkzeug:127.0.0.1 - - [08/Sep/2022 21:01:01] "POST /solve HTTP/1.1" 200 -
# INFO:Hops:Solving using legacy API: <HopsComponent /hello3 [FloorHeight,Width,Length,Rotation,SouthContextOffset,EastContextOffset,NorthContextOffset,WestContextOffset,SouthContextHeight,EastContextHeight,NorthContextHeight,WestContextHeight,SouthShadingDepth,EastShadingDepth,NorthShadingDepth,WestShadingDepth,NorthGlazingRatio,WestGlazingRatio,SouthGlazingRatio,EastGlazingRatio,NorthWindowHeight,WestWindowHeight,SouthWindowHeight,EastWindowHeight,NorthWindowSill,WestWindowSill,SouthWindowSill,EastWindowSill,Location -> Daylight Predictor -> sDA,UDI,ASE] >
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   "X does not have valid feature names, but"
# INFO:werkzeug:127.0.0.1 - - [08/Sep/2022 21:02:30] "POST /solve HTTP/1.1" 200 -
# INFO:Hops:Solving using legacy API: <HopsComponent /hello3 [FloorHeight,Width,Length,Rotation,SouthContextOffset,EastContextOffset,NorthContextOffset,WestContextOffset,SouthContextHeight,EastContextHeight,NorthContextHeight,WestContextHeight,SouthShadingDepth,EastShadingDepth,NorthShadingDepth,WestShadingDepth,NorthGlazingRatio,WestGlazingRatio,SouthGlazingRatio,EastGlazingRatio,NorthWindowHeight,WestWindowHeight,SouthWindowHeight,EastWindowHeight,NorthWindowSill,WestWindowSill,SouthWindowSill,EastWindowSill,Location -> Daylight Predictor -> sDA,UDI,ASE] >
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   "X does not have valid feature names, but"
# INFO:werkzeug:127.0.0.1 - - [08/Sep/2022 21:03:23] "POST /solve HTTP/1.1" 200 -
# INFO:Hops:Solving using legacy API: <HopsComponent /hello3 [FloorHeight,Width,Length,Rotation,SouthContextOffset,EastContextOffset,NorthContextOffset,WestContextOffset,SouthContextHeight,EastContextHeight,NorthContextHeight,WestContextHeight,SouthShadingDepth,EastShadingDepth,NorthShadingDepth,WestShadingDepth,NorthGlazingRatio,WestGlazingRatio,SouthGlazingRatio,EastGlazingRatio,NorthWindowHeight,WestWindowHeight,SouthWindowHeight,EastWindowHeight,NorthWindowSill,WestWindowSill,SouthWindowSill,EastWindowSill,Location -> Daylight Predictor -> sDA,UDI,ASE] >
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   "X does not have valid feature names, but"
# INFO:werkzeug:127.0.0.1 - - [08/Sep/2022 22:03:42] "POST /solve HTTP/1.1" 200 -
# INFO:Hops:Solving using legacy API: <HopsComponent /hello3 [FloorHeight,Width,Length,Rotation,SouthContextOffset,EastContextOffset,NorthContextOffset,WestContextOffset,SouthContextHeight,EastContextHeight,NorthContextHeight,WestContextHeight,SouthShadingDepth,EastShadingDepth,NorthShadingDepth,WestShadingDepth,NorthGlazingRatio,WestGlazingRatio,SouthGlazingRatio,EastGlazingRatio,NorthWindowHeight,WestWindowHeight,SouthWindowHeight,EastWindowHeight,NorthWindowSill,WestWindowSill,SouthWindowSill,EastWindowSill,Location -> Daylight Predictor -> sDA,UDI,ASE] >
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   "X does not have valid feature names, but"
# INFO:werkzeug:127.0.0.1 - - [08/Sep/2022 22:03:44] "POST /solve HTTP/1.1" 200 -
