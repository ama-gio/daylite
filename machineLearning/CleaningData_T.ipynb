# %% [markdown]
# ###0. Import

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import altair as alt
import tensorflow as tf
import math

sns.set(rc={'figure.figsize':(10,10)})
print("imports ok")
# Out:
# imports ok

# %%
#mount drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### 1. Clean data

# %%
# Load csv
data = pd.read_csv('/content/drive/MyDrive/0.Thesis/roomDaylightData_Thessaloniki.csv')

# %%
data
# Out:
#       roomNumber  FloorHeight  Width  Length  Rotation  SouthContextOffset  \
# 0              0          8.0     95      42     -22.0                  69
# 1              1          8.0     32      99       3.0                  69
# 2              2          7.0     46      21     -17.0                  80
# 3              3          7.0     60      87     -24.0                  31
# 4              4         10.0     53      87     -30.0                  14
# ...          ...          ...    ...     ...       ...                 ...
# 1825         446          9.0     55      94     -23.0                  19
# 1826         447          7.0     23      92     -21.0                  21
# 1827         448          7.0     23      92     -23.0                  21
# 1828         449          6.0     23      42     -16.0                   4
# 1829         450          9.0     23      88     -17.0                  21
#
#       EastContextOffset  NorthContextOffset  WestContextOffset  \
# 0                    12                  11                 71
# 1                    89                  86                 68
# 2                     9                  10                 43
# 3                    39                  10                 48
# 4                    85                  94                  9
# ...                 ...                 ...                ...
# 1825                 21                  73                 13
# 1826                 23                  69                 13
# 1827                 23                  69                 13
# 1828                 21                  69                 29
# 1829                 21                  72                 24
#
#       SouthContextHeight  ...       UDI9  ASE1  ASE2   ASE3  ASE4  ASE5  \
# 0                    161  ...  46.438776  5.82  4.76  57.77  0.00   0.0
# 1                    137  ...  70.683983  0.00  2.12  33.48  0.00   0.0
# 2                    499  ...        NaN   NaN   NaN    NaN   NaN   NaN
# 3                    437  ...  78.068966  2.93  3.88  23.97  0.00   0.0
# 4                     11  ...  26.208020  2.46  0.00  58.65  2.46   0.0
# ...                  ...  ...        ...   ...   ...    ...   ...   ...
# 1825                 137  ...  87.105287  0.00  0.00  10.17  0.00   0.0
# 1826                 202  ...  84.217486  0.00  0.00  13.55  0.00   0.0
# 1827                 202  ...  84.221858  0.00  0.00  12.57  0.00   0.0
# 1828                 171  ...        NaN   NaN   NaN    NaN   NaN   NaN
# 1829                 299  ...  87.789655  0.00  0.00   3.10  0.00   0.0
#
#        ASE6   ASE7   ASE8   ASE9
# 0     42.63   1.81   1.93  67.46
# 1     22.73   8.44  19.71  57.58
# 2       NaN    NaN    NaN    NaN
# 3     14.91   0.09   0.00  32.84
# 4     57.79  43.51  38.33  86.32
# ...     ...    ...    ...    ...
# 1825   1.57   0.13   0.54  26.48
# 1826   6.12   0.33   0.00  27.43
# 1827   6.34   0.44   0.00  26.01
# 1828    NaN    NaN    NaN    NaN
# 1829   0.46   0.23   0.00  31.03
#
# [1830 rows x 56 columns]

# %%
#drop rows with NaN data
data.dropna(axis=0, inplace=True)

# %%
data
# Out:
#       roomNumber  FloorHeight  Width  Length  Rotation  SouthContextOffset  \
# 0              0          8.0     95      42     -22.0                  69
# 1              1          8.0     32      99       3.0                  69
# 3              3          7.0     60      87     -24.0                  31
# 4              4         10.0     53      87     -30.0                  14
# 5              5          4.0     26      67     -24.0                  19
# ...          ...          ...    ...     ...       ...                 ...
# 1824         445          7.0     23      92     -17.0                  21
# 1825         446          9.0     55      94     -23.0                  19
# 1826         447          7.0     23      92     -21.0                  21
# 1827         448          7.0     23      92     -23.0                  21
# 1829         450          9.0     23      88     -17.0                  21
#
#       EastContextOffset  NorthContextOffset  WestContextOffset  \
# 0                    12                  11                 71
# 1                    89                  86                 68
# 3                    39                  10                 48
# 4                    85                  94                  9
# 5                    21                   4                 36
# ...                 ...                 ...                ...
# 1824                 23                  69                  9
# 1825                 21                  73                 13
# 1826                 23                  69                 13
# 1827                 23                  69                 13
# 1829                 21                  72                 24
#
#       SouthContextHeight  ...       UDI9  ASE1  ASE2   ASE3  ASE4  ASE5  \
# 0                    161  ...  46.438776  5.82  4.76  57.77  0.00   0.0
# 1                    137  ...  70.683983  0.00  2.12  33.48  0.00   0.0
# 3                    437  ...  78.068966  2.93  3.88  23.97  0.00   0.0
# 4                     11  ...  26.208020  2.46  0.00  58.65  2.46   0.0
# 5                    311  ...  76.038770  0.00  0.00  10.43  0.00   0.0
# ...                  ...  ...        ...   ...   ...    ...   ...   ...
# 1824                 202  ...  84.076503  0.00  0.00  13.44  0.00   0.0
# 1825                 137  ...  87.105287  0.00  0.00  10.17  0.00   0.0
# 1826                 202  ...  84.217486  0.00  0.00  13.55  0.00   0.0
# 1827                 202  ...  84.221858  0.00  0.00  12.57  0.00   0.0
# 1829                 299  ...  87.789655  0.00  0.00   3.10  0.00   0.0
#
#        ASE6   ASE7   ASE8   ASE9
# 0     42.63   1.81   1.93  67.46
# 1     22.73   8.44  19.71  57.58
# 3     14.91   0.09   0.00  32.84
# 4     57.79  43.51  38.33  86.32
# 5      6.95   0.00   0.00  15.78
# ...     ...    ...    ...    ...
# 1824   7.21   0.44   0.00  27.43
# 1825   1.57   0.13   0.54  26.48
# 1826   6.12   0.33   0.00  27.43
# 1827   6.34   0.44   0.00  26.01
# 1829   0.46   0.23   0.00  31.03
#
# [1666 rows x 56 columns]

# %% [markdown]
# ### 2. Parse Data

# %%
#repeat data 9 times
dataRepeat = data.loc[data.index.repeat(9)]

# %%
dataRepeat
# Out:
#       roomNumber  FloorHeight  Width  Length  Rotation  SouthContextOffset  \
# 0              0          8.0     95      42     -22.0                  69
# 0              0          8.0     95      42     -22.0                  69
# 0              0          8.0     95      42     -22.0                  69
# 0              0          8.0     95      42     -22.0                  69
# 0              0          8.0     95      42     -22.0                  69
# ...          ...          ...    ...     ...       ...                 ...
# 1829         450          9.0     23      88     -17.0                  21
# 1829         450          9.0     23      88     -17.0                  21
# 1829         450          9.0     23      88     -17.0                  21
# 1829         450          9.0     23      88     -17.0                  21
# 1829         450          9.0     23      88     -17.0                  21
#
#       EastContextOffset  NorthContextOffset  WestContextOffset  \
# 0                    12                  11                 71
# 0                    12                  11                 71
# 0                    12                  11                 71
# 0                    12                  11                 71
# 0                    12                  11                 71
# ...                 ...                 ...                ...
# 1829                 21                  72                 24
# 1829                 21                  72                 24
# 1829                 21                  72                 24
# 1829                 21                  72                 24
# 1829                 21                  72                 24
#
#       SouthContextHeight  ...       UDI9  ASE1  ASE2   ASE3  ASE4  ASE5  \
# 0                    161  ...  46.438776  5.82  4.76  57.77   0.0   0.0
# 0                    161  ...  46.438776  5.82  4.76  57.77   0.0   0.0
# 0                    161  ...  46.438776  5.82  4.76  57.77   0.0   0.0
# 0                    161  ...  46.438776  5.82  4.76  57.77   0.0   0.0
# 0                    161  ...  46.438776  5.82  4.76  57.77   0.0   0.0
# ...                  ...  ...        ...   ...   ...    ...   ...   ...
# 1829                 299  ...  87.789655  0.00  0.00   3.10   0.0   0.0
# 1829                 299  ...  87.789655  0.00  0.00   3.10   0.0   0.0
# 1829                 299  ...  87.789655  0.00  0.00   3.10   0.0   0.0
# 1829                 299  ...  87.789655  0.00  0.00   3.10   0.0   0.0
# 1829                 299  ...  87.789655  0.00  0.00   3.10   0.0   0.0
#
#        ASE6  ASE7  ASE8   ASE9
# 0     42.63  1.81  1.93  67.46
# 0     42.63  1.81  1.93  67.46
# 0     42.63  1.81  1.93  67.46
# 0     42.63  1.81  1.93  67.46
# 0     42.63  1.81  1.93  67.46
# ...     ...   ...   ...    ...
# 1829   0.46  0.23  0.00  31.03
# 1829   0.46  0.23  0.00  31.03
# 1829   0.46  0.23  0.00  31.03
# 1829   0.46  0.23  0.00  31.03
# 1829   0.46  0.23  0.00  31.03
#
# [14994 rows x 56 columns]

# %%
#add a column of the building number and change the index for the dataframe
myIndex = list(range(0,len(dataRepeat.index)))

dataRepeat['myIndex'] = myIndex
dataRepeat = dataRepeat.set_index('myIndex')

# %%
dataRepeat
# Out:
#          roomNumber  FloorHeight  Width  Length  Rotation  SouthContextOffset  \
# myIndex
# 0                 0          8.0     95      42     -22.0                  69
# 1                 0          8.0     95      42     -22.0                  69
# 2                 0          8.0     95      42     -22.0                  69
# 3                 0          8.0     95      42     -22.0                  69
# 4                 0          8.0     95      42     -22.0                  69
# ...             ...          ...    ...     ...       ...                 ...
# 14989           450          9.0     23      88     -17.0                  21
# 14990           450          9.0     23      88     -17.0                  21
# 14991           450          9.0     23      88     -17.0                  21
# 14992           450          9.0     23      88     -17.0                  21
# 14993           450          9.0     23      88     -17.0                  21
#
#          EastContextOffset  NorthContextOffset  WestContextOffset  \
# myIndex
# 0                       12                  11                 71
# 1                       12                  11                 71
# 2                       12                  11                 71
# 3                       12                  11                 71
# 4                       12                  11                 71
# ...                    ...                 ...                ...
# 14989                   21                  72                 24
# 14990                   21                  72                 24
# 14991                   21                  72                 24
# 14992                   21                  72                 24
# 14993                   21                  72                 24
#
#          SouthContextHeight  ...       UDI9  ASE1  ASE2   ASE3  ASE4  ASE5  \
# myIndex                      ...
# 0                       161  ...  46.438776  5.82  4.76  57.77   0.0   0.0
# 1                       161  ...  46.438776  5.82  4.76  57.77   0.0   0.0
# 2                       161  ...  46.438776  5.82  4.76  57.77   0.0   0.0
# 3                       161  ...  46.438776  5.82  4.76  57.77   0.0   0.0
# 4                       161  ...  46.438776  5.82  4.76  57.77   0.0   0.0
# ...                     ...  ...        ...   ...   ...    ...   ...   ...
# 14989                   299  ...  87.789655  0.00  0.00   3.10   0.0   0.0
# 14990                   299  ...  87.789655  0.00  0.00   3.10   0.0   0.0
# 14991                   299  ...  87.789655  0.00  0.00   3.10   0.0   0.0
# 14992                   299  ...  87.789655  0.00  0.00   3.10   0.0   0.0
# 14993                   299  ...  87.789655  0.00  0.00   3.10   0.0   0.0
#
#           ASE6  ASE7  ASE8   ASE9
# myIndex
# 0        42.63  1.81  1.93  67.46
# 1        42.63  1.81  1.93  67.46
# 2        42.63  1.81  1.93  67.46
# 3        42.63  1.81  1.93  67.46
# 4        42.63  1.81  1.93  67.46
# ...        ...   ...   ...    ...
# 14989     0.46  0.23  0.00  31.03
# 14990     0.46  0.23  0.00  31.03
# 14991     0.46  0.23  0.00  31.03
# 14992     0.46  0.23  0.00  31.03
# 14993     0.46  0.23  0.00  31.03
#
# [14994 rows x 56 columns]

# %%
#divide Length and Width by 3 to account for room layout of 3x3
dataRepeat['Width']= dataRepeat['Width']/3
dataRepeat['Length']= dataRepeat['Length']/3

# %%
#select every 9th row starting from 1st row
data1 = dataRepeat.iloc[::9, :]

#remove sDA, UDI and ASE columns for other numbers
data1 = data1.drop(columns = ['sDA2','sDA3','sDA4','sDA5','sDA6','sDA7','sDA8','sDA9','UDI2','UDI3','UDI4','UDI5','UDI6','UDI7','UDI8','UDI9','ASE2','ASE3','ASE4','ASE5','ASE6','ASE7','ASE8','ASE9'])

#rename remaining columns to not include number (sDA, UDI, ASE)
data1 = data1.rename(columns={"sDA1": "sDA", "UDI1": "UDI", "ASE1" : "ASE"})

#set orientation based features = 0 for blocked orientations
#data1.loc[:, data1.columns.str.contains('South')] = 0
#data1.loc[:, data1.columns.str.contains('East')] = 0
data1['SouthGlazingRatio']=0
data1['EastGlazingRatio']=0

# %%
#select every 9th row starting from 2nd row
data2 = dataRepeat.iloc[1::9, :]

#remove sDA, UDI and ASE columns for other numbers
data2 = data2.drop(columns = ['sDA1','sDA3','sDA4','sDA5','sDA6','sDA7','sDA8','sDA9','UDI1','UDI3','UDI4','UDI5','UDI6','UDI7','UDI8','UDI9','ASE1','ASE3','ASE4','ASE5','ASE6','ASE7','ASE8','ASE9'])

#rename remaining columns to not include number (sDA, UDI, ASE)
data2 = data2.rename(columns={"sDA2": "sDA", "UDI2": "UDI", "ASE2" : "ASE"})

#set orientation based features = 0 for blocked orientations
#data2.loc[:, data2.columns.str.contains('South')] = 0
#data2.loc[:, data2.columns.str.contains('East')] = 0
#data2.loc[:, data2.columns.str.contains('North')] = 0
data2['SouthGlazingRatio']=0
data2['EastGlazingRatio']=0
data2['NorthGlazingRatio']=0

# %%
#select every 9th row starting from 3rd row
data3 = dataRepeat.iloc[2::9, :]

#remove sDA, UDI and ASE columns for other numbers
data3 = data3.drop(columns = ['sDA2','sDA1','sDA4','sDA5','sDA6','sDA7','sDA8','sDA9','UDI2','UDI1','UDI4','UDI5','UDI6','UDI7','UDI8','UDI9','ASE2','ASE1','ASE4','ASE5','ASE6','ASE7','ASE8','ASE9'])

#rename remaining columns to not include number (sDA, UDI, ASE)
data3 = data3.rename(columns={"sDA3": "sDA", "UDI3": "UDI", "ASE3" : "ASE"})

#set orientation based features = 0 for blocked orientations
#data3.loc[:, data3.columns.str.contains('East')] = 0
#data3.loc[:, data3.columns.str.contains('North')] = 0
data3['EastGlazingRatio']=0
data3['NorthGlazingRatio']=0

# %%
#select every 9th row starting from 4th row
data4 = dataRepeat.iloc[3::9, :]

#remove sDA, UDI and ASE columns for other numbers
data4 = data4.drop(columns = ['sDA2','sDA3','sDA1','sDA5','sDA6','sDA7','sDA8','sDA9','UDI2','UDI3','UDI1','UDI5','UDI6','UDI7','UDI8','UDI9','ASE2','ASE3','ASE1','ASE5','ASE6','ASE7','ASE8','ASE9'])

#rename remaining columns to not include number (sDA, UDI, ASE)
data4 = data4.rename(columns={"sDA4": "sDA", "UDI4": "UDI", "ASE4" : "ASE"})

#set orientation based features = 0 for blocked orientations
#data4.loc[:, data4.columns.str.contains('East')] = 0
#data4.loc[:, data4.columns.str.contains('South')] = 0
#data4.loc[:, data4.columns.str.contains('West')] = 0
data4['SouthGlazingRatio']=0
data4['EastGlazingRatio']=0
data4['WestGlazingRatio']=0

# %%
#select every 9th row starting from 5th row
data5 = dataRepeat.iloc[4::9, :]

#remove sDA, UDI and ASE columns for other numbers
data5 = data5.drop(columns = ['sDA2','sDA3','sDA4','sDA1','sDA6','sDA7','sDA8','sDA9','UDI2','UDI3','UDI4','UDI1','UDI6','UDI7','UDI8','UDI9','ASE2','ASE3','ASE4','ASE1','ASE6','ASE7','ASE8','ASE9'])

#rename remaining columns to not include number (sDA, UDI, ASE)
data5 = data5.rename(columns={"sDA5": "sDA", "UDI5": "UDI", "ASE5" : "ASE"})

#set orientation based features = 0 for blocked orientations
#data5.loc[:, data5.columns.str.contains('East')] = 0
#data5.loc[:, data5.columns.str.contains('North')] = 0
#data5.loc[:, data5.columns.str.contains('South')] = 0
#data5.loc[:, data5.columns.str.contains('West')] = 0
data5['SouthGlazingRatio']=0
data5['EastGlazingRatio']=0
data5['NorthGlazingRatio']=0
data5['WestGlazingRatio']=0

# %%
#select every 9th row starting from 6th row
data6 = dataRepeat.iloc[5::9, :]

#remove sDA, UDI and ASE columns for other numbers
data6 = data6.drop(columns = ['sDA2','sDA3','sDA4','sDA5','sDA1','sDA7','sDA8','sDA9','UDI2','UDI3','UDI4','UDI5','UDI1','UDI7','UDI8','UDI9','ASE2','ASE3','ASE4','ASE5','ASE1','ASE7','ASE8','ASE9'])

#rename remaining columns to not include number (sDA, UDI, ASE)
data6 = data6.rename(columns={"sDA6": "sDA", "UDI6": "UDI", "ASE6" : "ASE"})

#set orientation based features = 0 for blocked orientations
#data6.loc[:, data6.columns.str.contains('East')] = 0
#data6.loc[:, data6.columns.str.contains('North')] = 0
#data6.loc[:, data6.columns.str.contains('West')] = 0
data6['EastGlazingRatio']=0
data6['NorthGlazingRatio']=0
data6['WestGlazingRatio']=0

# %%
#select every 9th row starting from 7th row
data7 = dataRepeat.iloc[6::9, :]

#remove sDA, UDI and ASE columns for other numbers
data7 = data7.drop(columns = ['sDA2','sDA3','sDA4','sDA5','sDA6','sDA1','sDA8','sDA9','UDI2','UDI3','UDI4','UDI5','UDI6','UDI1','UDI8','UDI9','ASE2','ASE3','ASE4','ASE5','ASE6','ASE1','ASE8','ASE9'])

#rename remaining columns to not include number (sDA, UDI, ASE)
data7= data7.rename(columns={"sDA7": "sDA", "UDI7": "UDI", "ASE7" : "ASE"})

#set orientation based features = 0 for blocked orientations
#data7.loc[:, data7.columns.str.contains('South')] = 0
#data7.loc[:, data7.columns.str.contains('West')] = 0
data7['SouthGlazingRatio']=0
data7['WestGlazingRatio']=0

# %%
#select every 9th row starting from 8th row
data8 = dataRepeat.iloc[7::9, :]

#remove sDA, UDI and ASE columns for other numbers
data8 = data8.drop(columns = ['sDA2','sDA3','sDA4','sDA5','sDA6','sDA7','sDA1','sDA9','UDI2','UDI3','UDI4','UDI5','UDI6','UDI7','UDI1','UDI9','ASE2','ASE3','ASE4','ASE5','ASE6','ASE7','ASE1','ASE9'])

#rename remaining columns to not include number (sDA, UDI, ASE)
data8= data8.rename(columns={"sDA8": "sDA", "UDI8": "UDI", "ASE8" : "ASE"})

#set orientation based features = 0 for blocked orientations
#data8.loc[:, data8.columns.str.contains('South')] = 0
#data8.loc[:, data8.columns.str.contains('North')] = 0
#data8.loc[:, data8.columns.str.contains('West')] = 0
data8['SouthGlazingRatio']=0
data8['NorthGlazingRatio']=0
data8['WestGlazingRatio']=0

# %%
#select every 9th row starting from 9th row
data9 = dataRepeat.iloc[8::9, :]

#remove sDA, UDI and ASE columns for other numbers
data9 = data9.drop(columns = ['sDA2','sDA3','sDA4','sDA5','sDA6','sDA7','sDA8','sDA1','UDI2','UDI3','UDI4','UDI5','UDI6','UDI7','UDI8','UDI1','ASE2','ASE3','ASE4','ASE5','ASE6','ASE7','ASE8','ASE1'])

#rename remaining columns to not include number (sDA, UDI, ASE)
data9 = data9.rename(columns={"sDA9": "sDA", "UDI9": "UDI", "ASE9" : "ASE"})

#set orientation based features = 0 for blocked orientations
#data9.loc[:, data9.columns.str.contains('North')] = 0
#data9.loc[:, data9.columns.str.contains('West')] = 0
data9['NorthGlazingRatio']=0
data9['WestGlazingRatio']=0

# %%
#combine dataframes and sort by myIndex
#don't include data5, it has all 0 values
frames = [data1, data2, data3, data4, data6, data7, data8, data9]

dataMod = pd.concat(frames)

dataMod = dataMod.sort_values(by=['myIndex'])

# %%
dataMod
# Out:
#          roomNumber  FloorHeight      Width     Length  Rotation  \
# myIndex
# 0                 0          8.0  31.666667  14.000000     -22.0
# 1                 0          8.0  31.666667  14.000000     -22.0
# 2                 0          8.0  31.666667  14.000000     -22.0
# 3                 0          8.0  31.666667  14.000000     -22.0
# 5                 0          8.0  31.666667  14.000000     -22.0
# ...             ...          ...        ...        ...       ...
# 14988           450          9.0   7.666667  29.333333     -17.0
# 14990           450          9.0   7.666667  29.333333     -17.0
# 14991           450          9.0   7.666667  29.333333     -17.0
# 14992           450          9.0   7.666667  29.333333     -17.0
# 14993           450          9.0   7.666667  29.333333     -17.0
#
#          SouthContextOffset  EastContextOffset  NorthContextOffset  \
# myIndex
# 0                        69                 12                  11
# 1                        69                 12                  11
# 2                        69                 12                  11
# 3                        69                 12                  11
# 5                        69                 12                  11
# ...                     ...                ...                 ...
# 14988                    21                 21                  72
# 14990                    21                 21                  72
# 14991                    21                 21                  72
# 14992                    21                 21                  72
# 14993                    21                 21                  72
#
#          WestContextOffset  SouthContextHeight  ...  WestWindowHeight  \
# myIndex                                         ...
# 0                       71                 161  ...                 4
# 1                       71                 161  ...                 4
# 2                       71                 161  ...                 4
# 3                       71                 161  ...                 4
# 5                       71                 161  ...                 4
# ...                    ...                 ...  ...               ...
# 14988                   24                 299  ...                 5
# 14990                   24                 299  ...                 5
# 14991                   24                 299  ...                 5
# 14992                   24                 299  ...                 5
# 14993                   24                 299  ...                 5
#
#          SouthWindowHeight  EastWindowHeight  NorthWindowSill  WestWindowSill  \
# myIndex
# 0                        6                 8                5               1
# 1                        6                 8                5               1
# 2                        6                 8                5               1
# 3                        6                 8                5               1
# 5                        6                 8                5               1
# ...                    ...               ...              ...             ...
# 14988                    4                 6                4               5
# 14990                    4                 6                4               5
# 14991                    4                 6                4               5
# 14992                    4                 6                4               5
# 14993                    4                 6                4               5
#
#          SouthWindowSill  EastWindowSill     sDA        UDI    ASE
# myIndex
# 0                      0               2   40.80  79.145797   5.82
# 1                      0               2   22.73  39.574263   4.76
# 2                      0               2  100.00  47.284580  57.77
# 3                      0               2    0.00  47.657260   0.00
# 5                      0               2  100.00  63.463152  42.63
# ...                  ...             ...     ...        ...    ...
# 14988                  5               4    0.00  11.316092   0.00
# 14990                  5               4    0.23  27.022989   0.46
# 14991                  5               4   47.24  91.527586   0.23
# 14992                  5               4    0.00  70.116092   0.00
# 14993                  5               4   84.14  87.789655  31.03
#
# [13328 rows x 32 columns]

# %% [markdown]
# ###3. Bin Data

# %%
#make column with binned areas for sDA
sDABin = pd.qcut(dataMod['sDA'], q=5, duplicates='drop')
dataMod['sDABin'] = sDABin

#make column with binned areas for UDI
UDIBin = pd.qcut(dataMod['UDI'], q=5)
dataMod['UDIBin'] = UDIBin

#make column with binned areas for ASE
ASEBin = pd.qcut(dataMod['ASE'], q=5, duplicates='drop')
dataMod['ASEBin'] = ASEBin

dataMod
# Out:
#          roomNumber  FloorHeight      Width     Length  Rotation  \
# myIndex
# 0                 0          8.0  31.666667  14.000000     -22.0
# 1                 0          8.0  31.666667  14.000000     -22.0
# 2                 0          8.0  31.666667  14.000000     -22.0
# 3                 0          8.0  31.666667  14.000000     -22.0
# 5                 0          8.0  31.666667  14.000000     -22.0
# ...             ...          ...        ...        ...       ...
# 14988           450          9.0   7.666667  29.333333     -17.0
# 14990           450          9.0   7.666667  29.333333     -17.0
# 14991           450          9.0   7.666667  29.333333     -17.0
# 14992           450          9.0   7.666667  29.333333     -17.0
# 14993           450          9.0   7.666667  29.333333     -17.0
#
#          SouthContextOffset  EastContextOffset  NorthContextOffset  \
# myIndex
# 0                        69                 12                  11
# 1                        69                 12                  11
# 2                        69                 12                  11
# 3                        69                 12                  11
# 5                        69                 12                  11
# ...                     ...                ...                 ...
# 14988                    21                 21                  72
# 14990                    21                 21                  72
# 14991                    21                 21                  72
# 14992                    21                 21                  72
# 14993                    21                 21                  72
#
#          WestContextOffset  SouthContextHeight  ...  NorthWindowSill  \
# myIndex                                         ...
# 0                       71                 161  ...                5
# 1                       71                 161  ...                5
# 2                       71                 161  ...                5
# 3                       71                 161  ...                5
# 5                       71                 161  ...                5
# ...                    ...                 ...  ...              ...
# 14988                   24                 299  ...                4
# 14990                   24                 299  ...                4
# 14991                   24                 299  ...                4
# 14992                   24                 299  ...                4
# 14993                   24                 299  ...                4
#
#          WestWindowSill  SouthWindowSill  EastWindowSill     sDA        UDI  \
# myIndex
# 0                     1                0               2   40.80  79.145797
# 1                     1                0               2   22.73  39.574263
# 2                     1                0               2  100.00  47.284580
# 3                     1                0               2    0.00  47.657260
# 5                     1                0               2  100.00  63.463152
# ...                 ...              ...             ...     ...        ...
# 14988                 5                5               4    0.00  11.316092
# 14990                 5                5               4    0.23  27.022989
# 14991                 5                5               4   47.24  91.527586
# 14992                 5                5               4    0.00  70.116092
# 14993                 5                5               4   84.14  87.789655
#
#            ASE          sDABin            UDIBin           ASEBin
# myIndex
# 0         5.82  (38.67, 80.77]  (73.968, 86.117]   (0.858, 12.32]
# 1         4.76   (12.3, 38.67]  (29.653, 53.629]   (0.858, 12.32]
# 2        57.77  (80.77, 100.0]  (29.653, 53.629]   (38.71, 100.0]
# 3         0.00  (-0.001, 12.3]  (29.653, 53.629]  (-0.001, 0.858]
# 5        42.63  (80.77, 100.0]  (53.629, 73.968]   (38.71, 100.0]
# ...        ...             ...               ...              ...
# 14988     0.00  (-0.001, 12.3]  (-0.001, 29.653]  (-0.001, 0.858]
# 14990     0.46  (-0.001, 12.3]  (-0.001, 29.653]  (-0.001, 0.858]
# 14991     0.23  (38.67, 80.77]  (86.117, 98.107]  (-0.001, 0.858]
# 14992     0.00  (-0.001, 12.3]  (53.629, 73.968]  (-0.001, 0.858]
# 14993    31.03  (80.77, 100.0]  (86.117, 98.107]   (12.32, 38.71]
#
# [13328 rows x 35 columns]

# %%
#copy these results in to the next cell
np.unique(dataMod['sDABin'])
# Out:
# array([Interval(-0.001, 12.3, closed='right'),
#        Interval(12.3, 38.67, closed='right'),
#        Interval(38.67, 80.77, closed='right'),
#        Interval(80.77, 100.0, closed='right')], dtype=object)

# %%
#change bin interval to categroical name for sDA
binSize_sDA = []
for value in dataMod['sDABin']:
  if value == pd.Interval(-0.001, 12.3, closed='right'):
    binSize_sDA.append('1')
  elif value == pd.Interval(12.3, 38.67, closed='right'):
    binSize_sDA.append('2')  
  elif value == pd.Interval(38.67, 80.77, closed='right'):
    binSize_sDA.append('3')  
  else:
    binSize_sDA.append('4')

# %%
#copy these results in to the next cell
np.unique(dataMod['UDIBin'])
# Out:
# array([Interval(-0.001, 29.653, closed='right'),
#        Interval(29.653, 53.629, closed='right'),
#        Interval(53.629, 73.968, closed='right'),
#        Interval(73.968, 86.117, closed='right'),
#        Interval(86.117, 98.107, closed='right')], dtype=object)

# %%
#change bin interval to categroical name for UDI
binSize_UDI = []
for value in dataMod['UDIBin']:
  if value == pd.Interval(-0.001, 29.653, closed='right'):
    binSize_UDI.append('1')
  elif value == pd.Interval(29.653, 53.629, closed='right'):
    binSize_UDI.append('2')  
  elif value == pd.Interval(53.629, 73.968, closed='right'):
    binSize_UDI.append('3')  
  elif value == pd.Interval(73.968, 86.117, closed='right'):
    binSize_UDI.append('4')  
  else:
    binSize_UDI.append('5')

# %%
#copy these results in to the next cell
np.unique(dataMod['ASEBin'])
# Out:
# array([Interval(-0.001, 0.858, closed='right'),
#        Interval(0.858, 12.32, closed='right'),
#        Interval(12.32, 38.71, closed='right'),
#        Interval(38.71, 100.0, closed='right')], dtype=object)

# %%
#change bin interval to categroical name for ASE
binSize_ASE = []
for value in dataMod['ASEBin']:
  if value == pd.Interval(-0.001, 0.858, closed='right'):
    binSize_ASE.append('1')
  elif value == pd.Interval(0.858, 12.32, closed='right'):
    binSize_ASE.append('2')  
  elif value == pd.Interval(12.32, 38.71, closed='right'):
    binSize_ASE.append('3')  
  else:
    binSize_ASE.append('4')

# %%
dataMod['sDA_Category'] = binSize_sDA
dataMod['UDI_Category'] = binSize_UDI
dataMod['ASE_Category'] = binSize_ASE

dataMod
# Out:
#          roomNumber  FloorHeight      Width     Length  Rotation  \
# myIndex
# 0                 0          8.0  31.666667  14.000000     -22.0
# 1                 0          8.0  31.666667  14.000000     -22.0
# 2                 0          8.0  31.666667  14.000000     -22.0
# 3                 0          8.0  31.666667  14.000000     -22.0
# 5                 0          8.0  31.666667  14.000000     -22.0
# ...             ...          ...        ...        ...       ...
# 14988           450          9.0   7.666667  29.333333     -17.0
# 14990           450          9.0   7.666667  29.333333     -17.0
# 14991           450          9.0   7.666667  29.333333     -17.0
# 14992           450          9.0   7.666667  29.333333     -17.0
# 14993           450          9.0   7.666667  29.333333     -17.0
#
#          SouthContextOffset  EastContextOffset  NorthContextOffset  \
# myIndex
# 0                        69                 12                  11
# 1                        69                 12                  11
# 2                        69                 12                  11
# 3                        69                 12                  11
# 5                        69                 12                  11
# ...                     ...                ...                 ...
# 14988                    21                 21                  72
# 14990                    21                 21                  72
# 14991                    21                 21                  72
# 14992                    21                 21                  72
# 14993                    21                 21                  72
#
#          WestContextOffset  SouthContextHeight  ...  EastWindowSill     sDA  \
# myIndex                                         ...
# 0                       71                 161  ...               2   40.80
# 1                       71                 161  ...               2   22.73
# 2                       71                 161  ...               2  100.00
# 3                       71                 161  ...               2    0.00
# 5                       71                 161  ...               2  100.00
# ...                    ...                 ...  ...             ...     ...
# 14988                   24                 299  ...               4    0.00
# 14990                   24                 299  ...               4    0.23
# 14991                   24                 299  ...               4   47.24
# 14992                   24                 299  ...               4    0.00
# 14993                   24                 299  ...               4   84.14
#
#                UDI    ASE          sDABin            UDIBin           ASEBin  \
# myIndex
# 0        79.145797   5.82  (38.67, 80.77]  (73.968, 86.117]   (0.858, 12.32]
# 1        39.574263   4.76   (12.3, 38.67]  (29.653, 53.629]   (0.858, 12.32]
# 2        47.284580  57.77  (80.77, 100.0]  (29.653, 53.629]   (38.71, 100.0]
# 3        47.657260   0.00  (-0.001, 12.3]  (29.653, 53.629]  (-0.001, 0.858]
# 5        63.463152  42.63  (80.77, 100.0]  (53.629, 73.968]   (38.71, 100.0]
# ...            ...    ...             ...               ...              ...
# 14988    11.316092   0.00  (-0.001, 12.3]  (-0.001, 29.653]  (-0.001, 0.858]
# 14990    27.022989   0.46  (-0.001, 12.3]  (-0.001, 29.653]  (-0.001, 0.858]
# 14991    91.527586   0.23  (38.67, 80.77]  (86.117, 98.107]  (-0.001, 0.858]
# 14992    70.116092   0.00  (-0.001, 12.3]  (53.629, 73.968]  (-0.001, 0.858]
# 14993    87.789655  31.03  (80.77, 100.0]  (86.117, 98.107]   (12.32, 38.71]
#
#          sDA_Category  UDI_Category  ASE_Category
# myIndex
# 0                   3             4             2
# 1                   2             2             2
# 2                   4             2             4
# 3                   1             2             1
# 5                   4             3             4
# ...               ...           ...           ...
# 14988               1             1             1
# 14990               1             1             1
# 14991               3             5             1
# 14992               1             3             1
# 14993               4             5             3
#
# [13328 rows x 38 columns]

# %% [markdown]
# ###4. Export Data

# %%
#export data
dataMod.to_csv('/content/drive/MyDrive/0.Thesis/binnedData_T.csv')
