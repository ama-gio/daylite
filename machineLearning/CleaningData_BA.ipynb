# %% [markdown]
# ###0. Import

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import altair as alt
import tensorflow as tf
import math

sns.set(rc={'figure.figsize':(10,10)})
print("imports ok")
# Out:
# imports ok

# %%
#mount drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### 1. Clean data

# %%
# Load csv
data = pd.read_csv('/content/drive/MyDrive/0.Thesis/roomDaylightData_BuenosAires.csv')

# %%
data
# Out:
#       roomNumber  FloorHeight  Width  Length  Rotation  SouthContextOffset  \
# 0            NaN          NaN    NaN     NaN       NaN                 NaN
# 1            0.0          4.0   17.0    82.0     -41.0                39.0
# 2            1.0          4.0   41.0    41.0     -36.0                27.0
# 3            2.0          8.0   17.0    41.0      42.0                60.0
# 4            3.0          6.0   90.0    80.0     -29.0                42.0
# ...          ...          ...    ...     ...       ...                 ...
# 1996      1995.0          5.0   27.0    26.0     -16.0                18.0
# 1997      1996.0         10.0   29.0    38.0     -16.0                 3.0
# 1998      1997.0          8.0   25.0    37.0     -16.0                20.0
# 1999      1998.0          6.0   23.0    23.0     -16.0                 3.0
# 2000      1999.0          8.0   24.0    27.0     -16.0                25.0
#
#       EastContextOffset  NorthContextOffset  WestContextOffset  \
# 0                   NaN                 NaN                NaN
# 1                  41.0                23.0               73.0
# 2                  69.0                69.0                3.0
# 3                  44.0                 9.0                6.0
# 4                  31.0                66.0               33.0
# ...                 ...                 ...                ...
# 1996               26.0                74.0               28.0
# 1997               15.0                74.0               30.0
# 1998               25.0                69.0               28.0
# 1999               26.0                69.0               29.0
# 2000               25.0                74.0               20.0
#
#       SouthContextHeight  ...       UDI9    ASE1   ASE2   ASE3   ASE4  ASE5  \
# 0                    NaN  ...        NaN     NaN    NaN    NaN    NaN   NaN
# 1                    2.0  ...  65.617845   78.62  49.66  50.84  13.30   0.0
# 2                    7.0  ...  86.801097   23.73   0.00   0.27  20.03   0.0
# 3                   26.0  ...  17.050505    8.08   0.00   0.00   1.01   0.0
# 4                  139.0  ...  82.070995   28.30   0.16   0.35  25.60   0.0
# ...                  ...  ...        ...     ...    ...    ...    ...   ...
# 1996               225.0  ...  94.366013   72.55   2.94   1.31  71.90   0.0
# 1997               224.0  ...  93.648421   10.95   4.21   3.37   0.00   0.0
# 1998               175.0  ...  95.833333   25.26   0.00   0.26  21.35   0.0
# 1999               225.0  ...  93.884444  100.00   5.78   7.11  98.22   0.0
# 2000               207.0  ...  86.329861   46.88   1.74   1.74  39.24   0.0
#
#       ASE6   ASE7   ASE8   ASE9
# 0      NaN    NaN    NaN    NaN
# 1      0.0  57.91  29.46  12.96
# 2      0.0  26.20   0.00   0.41
# 3      0.0  98.32  98.99  98.99
# 4      0.0  38.54  12.06  12.34
# ...    ...    ...    ...    ...
# 1996   0.0  95.42  24.22  12.42
# 1997   0.0  41.05  14.53   4.63
# 1998   0.0  72.14  27.34   8.85
# 1999   0.0  95.11  11.56   7.11
# 2000   0.0  84.72  39.24  22.92
#
# [2001 rows x 56 columns]

# %%
#drop rows with NaN data
data.dropna(axis=0, inplace=True)

# %%
data
# Out:
#       roomNumber  FloorHeight  Width  Length  Rotation  SouthContextOffset  \
# 1            0.0          4.0   17.0    82.0     -41.0                39.0
# 2            1.0          4.0   41.0    41.0     -36.0                27.0
# 3            2.0          8.0   17.0    41.0      42.0                60.0
# 4            3.0          6.0   90.0    80.0     -29.0                42.0
# 5            4.0          5.0   47.0    54.0     -21.0                31.0
# ...          ...          ...    ...     ...       ...                 ...
# 1996      1995.0          5.0   27.0    26.0     -16.0                18.0
# 1997      1996.0         10.0   29.0    38.0     -16.0                 3.0
# 1998      1997.0          8.0   25.0    37.0     -16.0                20.0
# 1999      1998.0          6.0   23.0    23.0     -16.0                 3.0
# 2000      1999.0          8.0   24.0    27.0     -16.0                25.0
#
#       EastContextOffset  NorthContextOffset  WestContextOffset  \
# 1                  41.0                23.0               73.0
# 2                  69.0                69.0                3.0
# 3                  44.0                 9.0                6.0
# 4                  31.0                66.0               33.0
# 5                  75.0                88.0               89.0
# ...                 ...                 ...                ...
# 1996               26.0                74.0               28.0
# 1997               15.0                74.0               30.0
# 1998               25.0                69.0               28.0
# 1999               26.0                69.0               29.0
# 2000               25.0                74.0               20.0
#
#       SouthContextHeight  ...       UDI9    ASE1   ASE2   ASE3   ASE4  ASE5  \
# 1                    2.0  ...  65.617845   78.62  49.66  50.84  13.30   0.0
# 2                    7.0  ...  86.801097   23.73   0.00   0.27  20.03   0.0
# 3                   26.0  ...  17.050505    8.08   0.00   0.00   1.01   0.0
# 4                  139.0  ...  82.070995   28.30   0.16   0.35  25.60   0.0
# 5                  114.0  ...  68.166667   39.96  17.20  18.28  23.57   0.0
# ...                  ...  ...        ...     ...    ...    ...    ...   ...
# 1996               225.0  ...  94.366013   72.55   2.94   1.31  71.90   0.0
# 1997               224.0  ...  93.648421   10.95   4.21   3.37   0.00   0.0
# 1998               175.0  ...  95.833333   25.26   0.00   0.26  21.35   0.0
# 1999               225.0  ...  93.884444  100.00   5.78   7.11  98.22   0.0
# 2000               207.0  ...  86.329861   46.88   1.74   1.74  39.24   0.0
#
#       ASE6   ASE7   ASE8   ASE9
# 1      0.0  57.91  29.46  12.96
# 2      0.0  26.20   0.00   0.41
# 3      0.0  98.32  98.99  98.99
# 4      0.0  38.54  12.06  12.34
# 5      0.0  52.96  22.40  18.19
# ...    ...    ...    ...    ...
# 1996   0.0  95.42  24.22  12.42
# 1997   0.0  41.05  14.53   4.63
# 1998   0.0  72.14  27.34   8.85
# 1999   0.0  95.11  11.56   7.11
# 2000   0.0  84.72  39.24  22.92
#
# [1773 rows x 56 columns]

# %% [markdown]
# ### 2. Parse Data

# %%
#repeat data 9 times
dataRepeat = data.loc[data.index.repeat(9)]

# %%
dataRepeat
# Out:
#       roomNumber  FloorHeight  Width  Length  Rotation  SouthContextOffset  \
# 1            0.0          4.0   17.0    82.0     -41.0                39.0
# 1            0.0          4.0   17.0    82.0     -41.0                39.0
# 1            0.0          4.0   17.0    82.0     -41.0                39.0
# 1            0.0          4.0   17.0    82.0     -41.0                39.0
# 1            0.0          4.0   17.0    82.0     -41.0                39.0
# ...          ...          ...    ...     ...       ...                 ...
# 2000      1999.0          8.0   24.0    27.0     -16.0                25.0
# 2000      1999.0          8.0   24.0    27.0     -16.0                25.0
# 2000      1999.0          8.0   24.0    27.0     -16.0                25.0
# 2000      1999.0          8.0   24.0    27.0     -16.0                25.0
# 2000      1999.0          8.0   24.0    27.0     -16.0                25.0
#
#       EastContextOffset  NorthContextOffset  WestContextOffset  \
# 1                  41.0                23.0               73.0
# 1                  41.0                23.0               73.0
# 1                  41.0                23.0               73.0
# 1                  41.0                23.0               73.0
# 1                  41.0                23.0               73.0
# ...                 ...                 ...                ...
# 2000               25.0                74.0               20.0
# 2000               25.0                74.0               20.0
# 2000               25.0                74.0               20.0
# 2000               25.0                74.0               20.0
# 2000               25.0                74.0               20.0
#
#       SouthContextHeight  ...       UDI9   ASE1   ASE2   ASE3   ASE4  ASE5  \
# 1                    2.0  ...  65.617845  78.62  49.66  50.84  13.30   0.0
# 1                    2.0  ...  65.617845  78.62  49.66  50.84  13.30   0.0
# 1                    2.0  ...  65.617845  78.62  49.66  50.84  13.30   0.0
# 1                    2.0  ...  65.617845  78.62  49.66  50.84  13.30   0.0
# 1                    2.0  ...  65.617845  78.62  49.66  50.84  13.30   0.0
# ...                  ...  ...        ...    ...    ...    ...    ...   ...
# 2000               207.0  ...  86.329861  46.88   1.74   1.74  39.24   0.0
# 2000               207.0  ...  86.329861  46.88   1.74   1.74  39.24   0.0
# 2000               207.0  ...  86.329861  46.88   1.74   1.74  39.24   0.0
# 2000               207.0  ...  86.329861  46.88   1.74   1.74  39.24   0.0
# 2000               207.0  ...  86.329861  46.88   1.74   1.74  39.24   0.0
#
#       ASE6   ASE7   ASE8   ASE9
# 1      0.0  57.91  29.46  12.96
# 1      0.0  57.91  29.46  12.96
# 1      0.0  57.91  29.46  12.96
# 1      0.0  57.91  29.46  12.96
# 1      0.0  57.91  29.46  12.96
# ...    ...    ...    ...    ...
# 2000   0.0  84.72  39.24  22.92
# 2000   0.0  84.72  39.24  22.92
# 2000   0.0  84.72  39.24  22.92
# 2000   0.0  84.72  39.24  22.92
# 2000   0.0  84.72  39.24  22.92
#
# [15957 rows x 56 columns]

# %%
#add a column of the building number and change the index for the dataframe
myIndex = list(range(0,len(dataRepeat.index)))

dataRepeat['myIndex'] = myIndex
dataRepeat = dataRepeat.set_index('myIndex')

# %%
dataRepeat
# Out:
#          roomNumber  FloorHeight  Width  Length  Rotation  SouthContextOffset  \
# myIndex
# 0               0.0          4.0   17.0    82.0     -41.0                39.0
# 1               0.0          4.0   17.0    82.0     -41.0                39.0
# 2               0.0          4.0   17.0    82.0     -41.0                39.0
# 3               0.0          4.0   17.0    82.0     -41.0                39.0
# 4               0.0          4.0   17.0    82.0     -41.0                39.0
# ...             ...          ...    ...     ...       ...                 ...
# 15952        1999.0          8.0   24.0    27.0     -16.0                25.0
# 15953        1999.0          8.0   24.0    27.0     -16.0                25.0
# 15954        1999.0          8.0   24.0    27.0     -16.0                25.0
# 15955        1999.0          8.0   24.0    27.0     -16.0                25.0
# 15956        1999.0          8.0   24.0    27.0     -16.0                25.0
#
#          EastContextOffset  NorthContextOffset  WestContextOffset  \
# myIndex
# 0                     41.0                23.0               73.0
# 1                     41.0                23.0               73.0
# 2                     41.0                23.0               73.0
# 3                     41.0                23.0               73.0
# 4                     41.0                23.0               73.0
# ...                    ...                 ...                ...
# 15952                 25.0                74.0               20.0
# 15953                 25.0                74.0               20.0
# 15954                 25.0                74.0               20.0
# 15955                 25.0                74.0               20.0
# 15956                 25.0                74.0               20.0
#
#          SouthContextHeight  ...       UDI9   ASE1   ASE2   ASE3   ASE4  ASE5  \
# myIndex                      ...
# 0                       2.0  ...  65.617845  78.62  49.66  50.84  13.30   0.0
# 1                       2.0  ...  65.617845  78.62  49.66  50.84  13.30   0.0
# 2                       2.0  ...  65.617845  78.62  49.66  50.84  13.30   0.0
# 3                       2.0  ...  65.617845  78.62  49.66  50.84  13.30   0.0
# 4                       2.0  ...  65.617845  78.62  49.66  50.84  13.30   0.0
# ...                     ...  ...        ...    ...    ...    ...    ...   ...
# 15952                 207.0  ...  86.329861  46.88   1.74   1.74  39.24   0.0
# 15953                 207.0  ...  86.329861  46.88   1.74   1.74  39.24   0.0
# 15954                 207.0  ...  86.329861  46.88   1.74   1.74  39.24   0.0
# 15955                 207.0  ...  86.329861  46.88   1.74   1.74  39.24   0.0
# 15956                 207.0  ...  86.329861  46.88   1.74   1.74  39.24   0.0
#
#          ASE6   ASE7   ASE8   ASE9
# myIndex
# 0         0.0  57.91  29.46  12.96
# 1         0.0  57.91  29.46  12.96
# 2         0.0  57.91  29.46  12.96
# 3         0.0  57.91  29.46  12.96
# 4         0.0  57.91  29.46  12.96
# ...       ...    ...    ...    ...
# 15952     0.0  84.72  39.24  22.92
# 15953     0.0  84.72  39.24  22.92
# 15954     0.0  84.72  39.24  22.92
# 15955     0.0  84.72  39.24  22.92
# 15956     0.0  84.72  39.24  22.92
#
# [15957 rows x 56 columns]

# %%
#divide Length and Width by 3 to account for room layout of 3x3
dataRepeat['Width']= dataRepeat['Width']/3
dataRepeat['Length']= dataRepeat['Length']/3

# %%
#select every 9th row starting from 1st row
data1 = dataRepeat.iloc[::9, :]

#remove sDA, UDI and ASE columns for other numbers
data1 = data1.drop(columns = ['sDA2','sDA3','sDA4','sDA5','sDA6','sDA7','sDA8','sDA9','UDI2','UDI3','UDI4','UDI5','UDI6','UDI7','UDI8','UDI9','ASE2','ASE3','ASE4','ASE5','ASE6','ASE7','ASE8','ASE9'])

#rename remaining columns to not include number (sDA, UDI, ASE)
data1 = data1.rename(columns={"sDA1": "sDA", "UDI1": "UDI", "ASE1" : "ASE"})

#set orientation based features = 0 for blocked orientations
#data1.loc[:, data1.columns.str.contains('South')] = 0
#data1.loc[:, data1.columns.str.contains('East')] = 0
data1['SouthGlazingRatio']=0
data1['EastGlazingRatio']=0

# %%
#select every 9th row starting from 2nd row
data2 = dataRepeat.iloc[1::9, :]

#remove sDA, UDI and ASE columns for other numbers
data2 = data2.drop(columns = ['sDA1','sDA3','sDA4','sDA5','sDA6','sDA7','sDA8','sDA9','UDI1','UDI3','UDI4','UDI5','UDI6','UDI7','UDI8','UDI9','ASE1','ASE3','ASE4','ASE5','ASE6','ASE7','ASE8','ASE9'])

#rename remaining columns to not include number (sDA, UDI, ASE)
data2 = data2.rename(columns={"sDA2": "sDA", "UDI2": "UDI", "ASE2" : "ASE"})

#set orientation based features = 0 for blocked orientations
#data2.loc[:, data2.columns.str.contains('South')] = 0
#data2.loc[:, data2.columns.str.contains('East')] = 0
#data2.loc[:, data2.columns.str.contains('North')] = 0
data2['SouthGlazingRatio']=0
data2['EastGlazingRatio']=0
data2['NorthGlazingRatio']=0

# %%
#select every 9th row starting from 3rd row
data3 = dataRepeat.iloc[2::9, :]

#remove sDA, UDI and ASE columns for other numbers
data3 = data3.drop(columns = ['sDA2','sDA1','sDA4','sDA5','sDA6','sDA7','sDA8','sDA9','UDI2','UDI1','UDI4','UDI5','UDI6','UDI7','UDI8','UDI9','ASE2','ASE1','ASE4','ASE5','ASE6','ASE7','ASE8','ASE9'])

#rename remaining columns to not include number (sDA, UDI, ASE)
data3 = data3.rename(columns={"sDA3": "sDA", "UDI3": "UDI", "ASE3" : "ASE"})

#set orientation based features = 0 for blocked orientations
#data3.loc[:, data3.columns.str.contains('East')] = 0
#data3.loc[:, data3.columns.str.contains('North')] = 0
data3['EastGlazingRatio']=0
data3['NorthGlazingRatio']=0

# %%
#select every 9th row starting from 4th row
data4 = dataRepeat.iloc[3::9, :]

#remove sDA, UDI and ASE columns for other numbers
data4 = data4.drop(columns = ['sDA2','sDA3','sDA1','sDA5','sDA6','sDA7','sDA8','sDA9','UDI2','UDI3','UDI1','UDI5','UDI6','UDI7','UDI8','UDI9','ASE2','ASE3','ASE1','ASE5','ASE6','ASE7','ASE8','ASE9'])

#rename remaining columns to not include number (sDA, UDI, ASE)
data4 = data4.rename(columns={"sDA4": "sDA", "UDI4": "UDI", "ASE4" : "ASE"})

#set orientation based features = 0 for blocked orientations
#data4.loc[:, data4.columns.str.contains('East')] = 0
#data4.loc[:, data4.columns.str.contains('South')] = 0
#data4.loc[:, data4.columns.str.contains('West')] = 0
data4['SouthGlazingRatio']=0
data4['EastGlazingRatio']=0
data4['WestGlazingRatio']=0

# %%
#select every 9th row starting from 5th row
data5 = dataRepeat.iloc[4::9, :]

#remove sDA, UDI and ASE columns for other numbers
data5 = data5.drop(columns = ['sDA2','sDA3','sDA4','sDA1','sDA6','sDA7','sDA8','sDA9','UDI2','UDI3','UDI4','UDI1','UDI6','UDI7','UDI8','UDI9','ASE2','ASE3','ASE4','ASE1','ASE6','ASE7','ASE8','ASE9'])

#rename remaining columns to not include number (sDA, UDI, ASE)
data5 = data5.rename(columns={"sDA5": "sDA", "UDI5": "UDI", "ASE5" : "ASE"})

#set orientation based features = 0 for blocked orientations
#data5.loc[:, data5.columns.str.contains('East')] = 0
#data5.loc[:, data5.columns.str.contains('North')] = 0
#data5.loc[:, data5.columns.str.contains('South')] = 0
#data5.loc[:, data5.columns.str.contains('West')] = 0
data5['SouthGlazingRatio']=0
data5['EastGlazingRatio']=0
data5['NorthGlazingRatio']=0
data5['WestGlazingRatio']=0

# %%
#select every 9th row starting from 6th row
data6 = dataRepeat.iloc[5::9, :]

#remove sDA, UDI and ASE columns for other numbers
data6 = data6.drop(columns = ['sDA2','sDA3','sDA4','sDA5','sDA1','sDA7','sDA8','sDA9','UDI2','UDI3','UDI4','UDI5','UDI1','UDI7','UDI8','UDI9','ASE2','ASE3','ASE4','ASE5','ASE1','ASE7','ASE8','ASE9'])

#rename remaining columns to not include number (sDA, UDI, ASE)
data6 = data6.rename(columns={"sDA6": "sDA", "UDI6": "UDI", "ASE6" : "ASE"})

#set orientation based features = 0 for blocked orientations
#data6.loc[:, data6.columns.str.contains('East')] = 0
#data6.loc[:, data6.columns.str.contains('North')] = 0
#data6.loc[:, data6.columns.str.contains('West')] = 0
data6['EastGlazingRatio']=0
data6['NorthGlazingRatio']=0
data6['WestGlazingRatio']=0

# %%
#select every 9th row starting from 7th row
data7 = dataRepeat.iloc[6::9, :]

#remove sDA, UDI and ASE columns for other numbers
data7 = data7.drop(columns = ['sDA2','sDA3','sDA4','sDA5','sDA6','sDA1','sDA8','sDA9','UDI2','UDI3','UDI4','UDI5','UDI6','UDI1','UDI8','UDI9','ASE2','ASE3','ASE4','ASE5','ASE6','ASE1','ASE8','ASE9'])

#rename remaining columns to not include number (sDA, UDI, ASE)
data7= data7.rename(columns={"sDA7": "sDA", "UDI7": "UDI", "ASE7" : "ASE"})

#set orientation based features = 0 for blocked orientations
#data7.loc[:, data7.columns.str.contains('South')] = 0
#data7.loc[:, data7.columns.str.contains('West')] = 0
data7['SouthGlazingRatio']=0
data7['WestGlazingRatio']=0

# %%
#select every 9th row starting from 8th row
data8 = dataRepeat.iloc[7::9, :]

#remove sDA, UDI and ASE columns for other numbers
data8 = data8.drop(columns = ['sDA2','sDA3','sDA4','sDA5','sDA6','sDA7','sDA1','sDA9','UDI2','UDI3','UDI4','UDI5','UDI6','UDI7','UDI1','UDI9','ASE2','ASE3','ASE4','ASE5','ASE6','ASE7','ASE1','ASE9'])

#rename remaining columns to not include number (sDA, UDI, ASE)
data8= data8.rename(columns={"sDA8": "sDA", "UDI8": "UDI", "ASE8" : "ASE"})

#set orientation based features = 0 for blocked orientations
#data8.loc[:, data8.columns.str.contains('South')] = 0
#data8.loc[:, data8.columns.str.contains('North')] = 0
#data8.loc[:, data8.columns.str.contains('West')] = 0
data8['SouthGlazingRatio']=0
data8['NorthGlazingRatio']=0
data8['WestGlazingRatio']=0

# %%
#select every 9th row starting from 9th row
data9 = dataRepeat.iloc[8::9, :]

#remove sDA, UDI and ASE columns for other numbers
data9 = data9.drop(columns = ['sDA2','sDA3','sDA4','sDA5','sDA6','sDA7','sDA8','sDA1','UDI2','UDI3','UDI4','UDI5','UDI6','UDI7','UDI8','UDI1','ASE2','ASE3','ASE4','ASE5','ASE6','ASE7','ASE8','ASE1'])

#rename remaining columns to not include number (sDA, UDI, ASE)
data9 = data9.rename(columns={"sDA9": "sDA", "UDI9": "UDI", "ASE9" : "ASE"})

#set orientation based features = 0 for blocked orientations
#data9.loc[:, data9.columns.str.contains('North')] = 0
#data9.loc[:, data9.columns.str.contains('West')] = 0
data9['NorthGlazingRatio']=0
data9['WestGlazingRatio']=0

# %%
#combine dataframes and sort by myIndex
#don't include data5, it has all 0 values
frames = [data1, data2, data3, data4, data6, data7, data8, data9]

dataMod = pd.concat(frames)

dataMod = dataMod.sort_values(by=['myIndex'])

# %%
dataMod
# Out:
#          roomNumber  FloorHeight     Width     Length  Rotation  \
# myIndex
# 0               0.0          4.0  5.666667  27.333333     -41.0
# 1               0.0          4.0  5.666667  27.333333     -41.0
# 2               0.0          4.0  5.666667  27.333333     -41.0
# 3               0.0          4.0  5.666667  27.333333     -41.0
# 5               0.0          4.0  5.666667  27.333333     -41.0
# ...             ...          ...       ...        ...       ...
# 15951        1999.0          8.0  8.000000   9.000000     -16.0
# 15953        1999.0          8.0  8.000000   9.000000     -16.0
# 15954        1999.0          8.0  8.000000   9.000000     -16.0
# 15955        1999.0          8.0  8.000000   9.000000     -16.0
# 15956        1999.0          8.0  8.000000   9.000000     -16.0
#
#          SouthContextOffset  EastContextOffset  NorthContextOffset  \
# myIndex
# 0                      39.0               41.0                23.0
# 1                      39.0               41.0                23.0
# 2                      39.0               41.0                23.0
# 3                      39.0               41.0                23.0
# 5                      39.0               41.0                23.0
# ...                     ...                ...                 ...
# 15951                  25.0               25.0                74.0
# 15953                  25.0               25.0                74.0
# 15954                  25.0               25.0                74.0
# 15955                  25.0               25.0                74.0
# 15956                  25.0               25.0                74.0
#
#          WestContextOffset  SouthContextHeight  ...  WestWindowHeight  \
# myIndex                                         ...
# 0                     73.0                 2.0  ...               7.0
# 1                     73.0                 2.0  ...               7.0
# 2                     73.0                 2.0  ...               7.0
# 3                     73.0                 2.0  ...               7.0
# 5                     73.0                 2.0  ...               7.0
# ...                    ...                 ...  ...               ...
# 15951                 20.0               207.0  ...               4.0
# 15953                 20.0               207.0  ...               4.0
# 15954                 20.0               207.0  ...               4.0
# 15955                 20.0               207.0  ...               4.0
# 15956                 20.0               207.0  ...               4.0
#
#          SouthWindowHeight  EastWindowHeight  NorthWindowSill  WestWindowSill  \
# myIndex
# 0                      2.0              10.0              3.0             2.0
# 1                      2.0              10.0              3.0             2.0
# 2                      2.0              10.0              3.0             2.0
# 3                      2.0              10.0              3.0             2.0
# 5                      2.0              10.0              3.0             2.0
# ...                    ...               ...              ...             ...
# 15951                  2.0               3.0              1.0             5.0
# 15953                  2.0               3.0              1.0             5.0
# 15954                  2.0               3.0              1.0             5.0
# 15955                  2.0               3.0              1.0             5.0
# 15956                  2.0               3.0              1.0             5.0
#
#          SouthWindowSill  EastWindowSill     sDA        UDI    ASE
# myIndex
# 0                    2.0             2.0  100.00  46.752525  78.62
# 1                    2.0             2.0  100.00  62.612795  49.66
# 2                    2.0             2.0  100.00  49.333333  50.84
# 3                    2.0             2.0   24.58  29.116162  13.30
# 5                    2.0             2.0   29.46  40.277778   0.00
# ...                  ...             ...     ...        ...    ...
# 15951                4.0             4.0   74.31  73.482639  39.24
# 15953                4.0             4.0   84.72  96.218750   0.00
# 15954                4.0             4.0  100.00  54.861111  84.72
# 15955                4.0             4.0   98.96  89.940972  39.24
# 15956                4.0             4.0  100.00  86.329861  22.92
#
# [14184 rows x 32 columns]

# %% [markdown]
# ###3. Bin Data

# %%
#make column with binned areas for sDA
sDABin = pd.qcut(dataMod['sDA'], q=5, duplicates='drop')
dataMod['sDABin'] = sDABin

#make column with binned areas for UDI
UDIBin = pd.qcut(dataMod['UDI'], q=5)
dataMod['UDIBin'] = UDIBin

#make column with binned areas for ASE
ASEBin = pd.qcut(dataMod['ASE'], q=5, duplicates='drop')
dataMod['ASEBin'] = ASEBin

dataMod
# Out:
#          roomNumber  FloorHeight     Width     Length  Rotation  \
# myIndex
# 0               0.0          4.0  5.666667  27.333333     -41.0
# 1               0.0          4.0  5.666667  27.333333     -41.0
# 2               0.0          4.0  5.666667  27.333333     -41.0
# 3               0.0          4.0  5.666667  27.333333     -41.0
# 5               0.0          4.0  5.666667  27.333333     -41.0
# ...             ...          ...       ...        ...       ...
# 15951        1999.0          8.0  8.000000   9.000000     -16.0
# 15953        1999.0          8.0  8.000000   9.000000     -16.0
# 15954        1999.0          8.0  8.000000   9.000000     -16.0
# 15955        1999.0          8.0  8.000000   9.000000     -16.0
# 15956        1999.0          8.0  8.000000   9.000000     -16.0
#
#          SouthContextOffset  EastContextOffset  NorthContextOffset  \
# myIndex
# 0                      39.0               41.0                23.0
# 1                      39.0               41.0                23.0
# 2                      39.0               41.0                23.0
# 3                      39.0               41.0                23.0
# 5                      39.0               41.0                23.0
# ...                     ...                ...                 ...
# 15951                  25.0               25.0                74.0
# 15953                  25.0               25.0                74.0
# 15954                  25.0               25.0                74.0
# 15955                  25.0               25.0                74.0
# 15956                  25.0               25.0                74.0
#
#          WestContextOffset  SouthContextHeight  ...  NorthWindowSill  \
# myIndex                                         ...
# 0                     73.0                 2.0  ...              3.0
# 1                     73.0                 2.0  ...              3.0
# 2                     73.0                 2.0  ...              3.0
# 3                     73.0                 2.0  ...              3.0
# 5                     73.0                 2.0  ...              3.0
# ...                    ...                 ...  ...              ...
# 15951                 20.0               207.0  ...              1.0
# 15953                 20.0               207.0  ...              1.0
# 15954                 20.0               207.0  ...              1.0
# 15955                 20.0               207.0  ...              1.0
# 15956                 20.0               207.0  ...              1.0
#
#          WestWindowSill  SouthWindowSill  EastWindowSill     sDA        UDI  \
# myIndex
# 0                   2.0              2.0             2.0  100.00  46.752525
# 1                   2.0              2.0             2.0  100.00  62.612795
# 2                   2.0              2.0             2.0  100.00  49.333333
# 3                   2.0              2.0             2.0   24.58  29.116162
# 5                   2.0              2.0             2.0   29.46  40.277778
# ...                 ...              ...             ...     ...        ...
# 15951               5.0              4.0             4.0   74.31  73.482639
# 15953               5.0              4.0             4.0   84.72  96.218750
# 15954               5.0              4.0             4.0  100.00  54.861111
# 15955               5.0              4.0             4.0   98.96  89.940972
# 15956               5.0              4.0             4.0  100.00  86.329861
#
#            ASE          sDABin            UDIBin          ASEBin
# myIndex
# 0        78.62  (91.47, 100.0]  (40.288, 64.719]  (41.09, 100.0]
# 1        49.66  (91.47, 100.0]  (40.288, 64.719]  (41.09, 100.0]
# 2        50.84  (91.47, 100.0]  (40.288, 64.719]  (41.09, 100.0]
# 3        13.30  (16.03, 52.94]  (-0.001, 40.288]   (3.74, 16.56]
# 5         0.00  (16.03, 52.94]  (-0.001, 40.288]  (-0.001, 3.74]
# ...        ...             ...               ...             ...
# 15951    39.24  (52.94, 91.47]  (64.719, 78.711]  (16.56, 41.09]
# 15953     0.00  (52.94, 91.47]  (87.267, 96.724]  (-0.001, 3.74]
# 15954    84.72  (91.47, 100.0]  (40.288, 64.719]  (41.09, 100.0]
# 15955    39.24  (91.47, 100.0]  (87.267, 96.724]  (16.56, 41.09]
# 15956    22.92  (91.47, 100.0]  (78.711, 87.267]  (16.56, 41.09]
#
# [14184 rows x 35 columns]

# %%
#copy these results in to the next cell
np.unique(dataMod['sDABin'])
# Out:
# array([Interval(-0.001, 16.03, closed='right'),
#        Interval(16.03, 52.94, closed='right'),
#        Interval(52.94, 91.47, closed='right'),
#        Interval(91.47, 100.0, closed='right')], dtype=object)

# %%
#change bin interval to categroical name for sDA
binSize_sDA = []
for value in dataMod['sDABin']:
  if value == pd.Interval(-0.001, 16.03, closed='right'):
    binSize_sDA.append('1')
  elif value == pd.Interval(16.03, 52.94, closed='right'):
    binSize_sDA.append('2')  
  elif value == pd.Interval(52.94, 91.47, closed='right'):
    binSize_sDA.append('3')  
  else:
    binSize_sDA.append('4')

# %%
#copy these results in to the next cell
np.unique(dataMod['UDIBin'])
# Out:
# array([Interval(-0.001, 40.288, closed='right'),
#        Interval(40.288, 64.719, closed='right'),
#        Interval(64.719, 78.711, closed='right'),
#        Interval(78.711, 87.267, closed='right'),
#        Interval(87.267, 96.724, closed='right')], dtype=object)

# %%
#change bin interval to categroical name for UDI
binSize_UDI = []
for value in dataMod['UDIBin']:
  if value == pd.Interval(-0.001, 40.288, closed='right'):
    binSize_UDI.append('1')
  elif value == pd.Interval(40.288, 64.719, closed='right'):
    binSize_UDI.append('2')  
  elif value == pd.Interval(64.719, 78.711, closed='right'):
    binSize_UDI.append('3')  
  elif value == pd.Interval(78.711, 87.267, closed='right'):
    binSize_UDI.append('4')  
  else:
    binSize_UDI.append('5')

# %%
#copy these results in to the next cell
np.unique(dataMod['ASEBin'])
# Out:
# array([Interval(-0.001, 3.74, closed='right'),
#        Interval(3.74, 16.56, closed='right'),
#        Interval(16.56, 41.09, closed='right'),
#        Interval(41.09, 100.0, closed='right')], dtype=object)

# %%
#change bin interval to categroical name for ASE
binSize_ASE = []
for value in dataMod['ASEBin']:
  if value == pd.Interval(-0.001, 3.74, closed='right'):
    binSize_ASE.append('1')
  elif value == pd.Interval(3.74, 16.56, closed='right'):
    binSize_ASE.append('2')  
  elif value == pd.Interval(16.56, 41.09, closed='right'):
    binSize_ASE.append('3')  
  else:
    binSize_ASE.append('4')

# %%
dataMod['sDA_Category'] = binSize_sDA
dataMod['UDI_Category'] = binSize_UDI
dataMod['ASE_Category'] = binSize_ASE

dataMod
# Out:
#          roomNumber  FloorHeight     Width     Length  Rotation  \
# myIndex
# 0               0.0          4.0  5.666667  27.333333     -41.0
# 1               0.0          4.0  5.666667  27.333333     -41.0
# 2               0.0          4.0  5.666667  27.333333     -41.0
# 3               0.0          4.0  5.666667  27.333333     -41.0
# 5               0.0          4.0  5.666667  27.333333     -41.0
# ...             ...          ...       ...        ...       ...
# 15951        1999.0          8.0  8.000000   9.000000     -16.0
# 15953        1999.0          8.0  8.000000   9.000000     -16.0
# 15954        1999.0          8.0  8.000000   9.000000     -16.0
# 15955        1999.0          8.0  8.000000   9.000000     -16.0
# 15956        1999.0          8.0  8.000000   9.000000     -16.0
#
#          SouthContextOffset  EastContextOffset  NorthContextOffset  \
# myIndex
# 0                      39.0               41.0                23.0
# 1                      39.0               41.0                23.0
# 2                      39.0               41.0                23.0
# 3                      39.0               41.0                23.0
# 5                      39.0               41.0                23.0
# ...                     ...                ...                 ...
# 15951                  25.0               25.0                74.0
# 15953                  25.0               25.0                74.0
# 15954                  25.0               25.0                74.0
# 15955                  25.0               25.0                74.0
# 15956                  25.0               25.0                74.0
#
#          WestContextOffset  SouthContextHeight  ...  EastWindowSill     sDA  \
# myIndex                                         ...
# 0                     73.0                 2.0  ...             2.0  100.00
# 1                     73.0                 2.0  ...             2.0  100.00
# 2                     73.0                 2.0  ...             2.0  100.00
# 3                     73.0                 2.0  ...             2.0   24.58
# 5                     73.0                 2.0  ...             2.0   29.46
# ...                    ...                 ...  ...             ...     ...
# 15951                 20.0               207.0  ...             4.0   74.31
# 15953                 20.0               207.0  ...             4.0   84.72
# 15954                 20.0               207.0  ...             4.0  100.00
# 15955                 20.0               207.0  ...             4.0   98.96
# 15956                 20.0               207.0  ...             4.0  100.00
#
#                UDI    ASE          sDABin            UDIBin          ASEBin  \
# myIndex
# 0        46.752525  78.62  (91.47, 100.0]  (40.288, 64.719]  (41.09, 100.0]
# 1        62.612795  49.66  (91.47, 100.0]  (40.288, 64.719]  (41.09, 100.0]
# 2        49.333333  50.84  (91.47, 100.0]  (40.288, 64.719]  (41.09, 100.0]
# 3        29.116162  13.30  (16.03, 52.94]  (-0.001, 40.288]   (3.74, 16.56]
# 5        40.277778   0.00  (16.03, 52.94]  (-0.001, 40.288]  (-0.001, 3.74]
# ...            ...    ...             ...               ...             ...
# 15951    73.482639  39.24  (52.94, 91.47]  (64.719, 78.711]  (16.56, 41.09]
# 15953    96.218750   0.00  (52.94, 91.47]  (87.267, 96.724]  (-0.001, 3.74]
# 15954    54.861111  84.72  (91.47, 100.0]  (40.288, 64.719]  (41.09, 100.0]
# 15955    89.940972  39.24  (91.47, 100.0]  (87.267, 96.724]  (16.56, 41.09]
# 15956    86.329861  22.92  (91.47, 100.0]  (78.711, 87.267]  (16.56, 41.09]
#
#          sDA_Category  UDI_Category  ASE_Category
# myIndex
# 0                   4             2             4
# 1                   4             2             4
# 2                   4             2             4
# 3                   2             1             2
# 5                   2             1             1
# ...               ...           ...           ...
# 15951               3             3             3
# 15953               3             5             1
# 15954               4             2             4
# 15955               4             5             3
# 15956               4             4             3
#
# [14184 rows x 38 columns]

# %% [markdown]
# ###4. Export Data

# %%
#export data
dataMod.to_csv('/content/drive/MyDrive/0.Thesis/binnedData_BA.csv')
